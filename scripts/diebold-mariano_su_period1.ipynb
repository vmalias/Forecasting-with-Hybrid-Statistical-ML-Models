# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from typing import Dict
import warnings
warnings.filterwarnings('ignore')

# ============================================
# 1. LOAD ALL PREDICTION FILES
# ============================================

print("="*60)
print("DIEBOLD-MARIANO TESTS (α = 0.05)")
print("="*60)

# Load all CSV files
models_data = {
    'LSTM': pd.read_csv('lstm.csv', parse_dates=['Date']),
    'XGBoost': pd.read_csv('xgboost.csv', parse_dates=['Date']),
    'ARIMA': pd.read_csv('arima.csv', parse_dates=['Date']),
    'ARIMA-LSTM': pd.read_csv('arima_lstm.csv', parse_dates=['Date']),
    'ARIMA-XGBoost': pd.read_csv('arima_xgboost.csv', parse_dates=['Date']),
    'LSTM-XGBoost': pd.read_csv('lstm_xgboost.csv', parse_dates=['Date'])
}

# Standardize column names for consistency
for model_name, df in models_data.items():
    # Find the prediction column (non-Date, non-Actual)
    pred_col = [col for col in df.columns if col not in ['Date', 'Actual']][0]
    # Rename prediction column to standardized name
    df.rename(columns={pred_col: f'{model_name}_Predicted'}, inplace=True)

# Create a unified DataFrame with all predictions
unified_df = models_data['ARIMA'][['Date', 'Actual']].copy()

for model_name, df in models_data.items():
    pred_col = f'{model_name}_Predicted'
    unified_df[pred_col] = df[pred_col]

print("Loaded all prediction files:")
print(f"Total observations: {len(unified_df)}")
print(f"Date range: {unified_df['Date'].min().date()} to {unified_df['Date'].max().date()}")
print(f"Models: {list(models_data.keys())}")

# ============================================
# 2. CALCULATE RESIDUALS AND PERFORMANCE METRICS
# ============================================

print("\n" + "="*60)
print("MODEL PERFORMANCE METRICS")
print("="*60)

# Calculate residuals and performance metrics
metrics = {}
residuals_dict = {}

for model_name in models_data.keys():
    pred_col = f'{model_name}_Predicted'
    residuals = unified_df['Actual'] - unified_df[pred_col]
    residuals_dict[model_name] = residuals
    
    # Calculate metrics
    mse = np.mean(residuals**2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(residuals))
    mape = np.mean(np.abs(residuals / unified_df['Actual'])) * 100
    
    metrics[model_name] = {
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae,
        'MAPE': mape,
        'Mean_Residual': np.mean(residuals),
        'Std_Residual': np.std(residuals)
    }

# Create performance DataFrame
metrics_df = pd.DataFrame(metrics).T
metrics_df = metrics_df.sort_values('RMSE')

print("\nPerformance Metrics (sorted by RMSE):")
print("-" * 80)
print(metrics_df.round(4).to_string())
print("\n" + "-" * 80)
print(f"Best model by RMSE: {metrics_df.index[0]} ({metrics_df.iloc[0]['RMSE']:.2f})")
print(f"Worst model by RMSE: {metrics_df.index[-1]} ({metrics_df.iloc[-1]['RMSE']:.2f})")

# ============================================
# 3. DIEBOLD-MARIANO TEST IMPLEMENTATION (α = 0.05)
# ============================================

def diebold_mariano_test(residuals1: pd.Series, residuals2: pd.Series, 
                        h: int = 1, loss_type: str = 'squared') -> Dict:
    """
    Perform Diebold-Mariano test for comparing two forecast models.
    
    Parameters:
    -----------
    residuals1 : pd.Series
        Residuals from model 1 (actual - predicted)
    residuals2 : pd.Series
        Residuals from model 2 (actual - predicted)
    h : int
        Forecast horizon (default=1 for one-step ahead)
    loss_type : str
        Loss function: 'squared' (MSE) or 'absolute' (MAE)
    
    Returns:
    --------
    dict : Test results including DM statistic and p-values
    """
    from scipy.stats import norm
    
    # Ensure equal length
    n = min(len(residuals1), len(residuals2))
    residuals1 = residuals1.iloc[:n]
    residuals2 = residuals2.iloc[:n]
    
    # Calculate loss differential
    if loss_type == 'squared':
        d = residuals1**2 - residuals2**2
    elif loss_type == 'absolute':
        d = np.abs(residuals1) - np.abs(residuals2)
    else:
        raise ValueError("loss_type must be 'squared' or 'absolute'")
    
    # Calculate mean and variance of loss differential
    mean_d = np.mean(d)
    var_d = np.var(d, ddof=1)  # Sample variance
    
    # Calculate DM statistic
    dm_stat = mean_d / np.sqrt(var_d / n)
    
    # Calculate p-values (two-tailed test)
    p_value_two_tailed = 2 * (1 - norm.cdf(abs(dm_stat)))
    p_value_one_tailed_better = 1 - norm.cdf(dm_stat)  # H1: model2 better than model1
    p_value_one_tailed_worse = norm.cdf(dm_stat)       # H1: model2 worse than model1
    
    # Bartlett's small-sample correction
    #bartlett_factor = 1 + (h - 1) / n
    dm_stat_corrected = dm_stat #/ np.sqrt(bartlett_factor)
    p_value_two_tailed_corrected = 2 * (1 - norm.cdf(abs(dm_stat_corrected)))
    
    return {
        'DM_Statistic': dm_stat,
        'DM_Statistic_Corrected': dm_stat_corrected,
        'P_Value_Two_Tailed': p_value_two_tailed,
        'P_Value_Two_Tailed_Corrected': p_value_two_tailed_corrected,
        'P_Value_One_Tailed_Better': p_value_one_tailed_better,
        'P_Value_One_Tailed_Worse': p_value_one_tailed_worse,
        'Mean_Loss_Differential': mean_d,
        'Std_Loss_Differential': np.sqrt(var_d),
        'Sample_Size': n,
        'Loss_Type': loss_type
    }

# ============================================
# 4. PERFORM PAIRWISE DIEBOLD-MARIANO TESTS (α = 0.05)
# ============================================

print("\n" + "="*80)
print("DIEBOLD-MARIANO TESTS - MODEL COMPARISONS (α = 0.05)")
print("="*80)

# Get model names in sorted order by RMSE (best to worst)
model_names_sorted = list(metrics_df.index)

# Perform pairwise DM tests
dm_results = {}
model_pairs = []

for i, model1 in enumerate(model_names_sorted):
    for model2 in model_names_sorted[i+1:]:
        pair_key = f"{model1} vs {model2}"
        model_pairs.append(pair_key)
        
        # Get residuals
        res1 = residuals_dict[model1]
        res2 = residuals_dict[model2]
        
        # Perform DM test with both loss functions
        dm_squared = diebold_mariano_test(res1, res2, h=1, loss_type='squared')
        dm_absolute = diebold_mariano_test(res1, res2, h=1, loss_type='absolute')
        
        dm_results[pair_key] = {
            'Squared_Error': dm_squared,
            'Absolute_Error': dm_absolute
        }

# ============================================
# 5. DISPLAY DM TEST RESULTS WITH CRITICAL VALUES
# ============================================

# Critical values for α = 0.05
critical_value_two_tailed = norm.ppf(1 - 0.05/2)  # ±1.96 for two-tailed
critical_value_one_tailed = norm.ppf(1 - 0.05)    # 1.645 for one-tailed

print("\n" + "="*80)
print("DIEBOLD-MARIANO TEST RESULTS (Squared Error Loss)")
print("="*80)
print("\nH₀: The two models have equal predictive accuracy")
print("H₁: The two models have different predictive accuracy")
print(f"Significance level: α = 0.05")
print(f"Critical values: ±{critical_value_two_tailed:.3f} (two-tailed), {critical_value_one_tailed:.3f} (one-tailed)")
print("\nDECISION RULE:")
print(f"- Reject H₀ if |DM Statistic| > {critical_value_two_tailed:.3f} (two-tailed)")
print(f"- Reject H₀ if DM Statistic > {critical_value_one_tailed:.3f} (model 2 better than model 1)")
print(f"- Reject H₀ if DM Statistic < -{critical_value_one_tailed:.3f} (model 1 better than model 2)\n")

print(f"{'Model Pair':<25} {'DM Stat':<10} {'P-Value':<12} {'Sig.':<8} {'Reject H₀?':<12} {'Conclusion':<30}")
print("-" * 107)

for pair in model_pairs:
    dm_info = dm_results[pair]['Squared_Error']
    dm_stat = dm_info['DM_Statistic_Corrected']
    p_value = dm_info['P_Value_Two_Tailed_Corrected']
    abs_dm_stat = abs(dm_stat)
    
    # Determine if we reject H₀
    reject_h0 = "YES" if abs_dm_stat > critical_value_two_tailed else "NO"
    
    # Determine significance (α = 0.05)
    if p_value < 0.01:
        sig = "***"
    elif p_value < 0.05:
        sig = "**"
    else:
        sig = ""
    
    # Determine which model is better
    model1, model2 = pair.split(" vs ")
    mean_diff = dm_info['Mean_Loss_Differential']
    
    if mean_diff > 0:
        # Model1 has higher loss (worse) than Model2
        better_model = model2
        worse_model = model1
        conclusion = f"{model2} better than {model1}"
    else:
        # Model1 has lower loss (better) than Model2
        better_model = model1
        worse_model = model2
        conclusion = f"{model1} better than {model2}"
    
    # Only show conclusion if significant at 5% level (α = 0.05)
    if p_value >= 0.05:
        conclusion = "No significant difference"
    
    print(f"{pair:<25} {dm_stat:>8.3f} {p_value:>11.4f} {sig:^8} {reject_h0:^12} {conclusion:<30}")

print("\n" + "="*80)
print("DIEBOLD-MARIANO TEST RESULTS (Absolute Error Loss)")
print("="*80)
print("\nH₀: The two models have equal predictive accuracy")
print("H₁: The two models have different predictive accuracy")
print(f"Significance level: α = 0.05")
print(f"Critical values: ±{critical_value_two_tailed:.3f} (two-tailed), {critical_value_one_tailed:.3f} (one-tailed)")
print("\nDECISION RULE:")
print(f"- Reject H₀ if |DM Statistic| > {critical_value_two_tailed:.3f} (two-tailed)")
print(f"- Reject H₀ if DM Statistic > {critical_value_one_tailed:.3f} (model 2 better than model 1)")
print(f"- Reject H₀ if DM Statistic < -{critical_value_one_tailed:.3f} (model 1 better than model 2)\n")

print(f"{'Model Pair':<25} {'DM Stat':<10} {'P-Value':<12} {'Sig.':<8} {'Reject H₀?':<12} {'Conclusion':<30}")
print("-" * 107)

for pair in model_pairs:
    dm_info = dm_results[pair]['Absolute_Error']
    dm_stat = dm_info['DM_Statistic_Corrected']
    p_value = dm_info['P_Value_Two_Tailed_Corrected']
    abs_dm_stat = abs(dm_stat)
    
    # Determine if we reject H₀
    reject_h0 = "YES" if abs_dm_stat > critical_value_two_tailed else "NO"
    
    # Determine significance (α = 0.05)
    if p_value < 0.01:
        sig = "***"
    elif p_value < 0.05:
        sig = "**"
    else:
        sig = ""
    
    # Determine which model is better
    model1, model2 = pair.split(" vs ")
    mean_diff = dm_info['Mean_Loss_Differential']
    
    if mean_diff > 0:
        # Model1 has higher loss (worse) than Model2
        better_model = model2
        worse_model = model1
        conclusion = f"{model2} better than {model1}"
    else:
        # Model1 has lower loss (better) than Model2
        better_model = model1
        worse_model = model2
        conclusion = f"{model1} better than {model2}"
    
    # Only show conclusion if significant at 5% level (α = 0.05)
    if p_value >= 0.05:
        conclusion = "No significant difference"
    
    print(f"{pair:<25} {dm_stat:>8.3f} {p_value:>11.4f} {sig:^8} {reject_h0:^12} {conclusion:<30}")

# ============================================
# 6. CREATE SUMMARY OF SIGNIFICANT DIFFERENCES (α = 0.05)
# ============================================

print("\n" + "="*80)
print("SUMMARY OF SIGNIFICANT DIFFERENCES (α = 0.05)")
print("="*80)
print(f"Critical value for rejection: |DM| > {critical_value_two_tailed:.3f}")

print("\nSIGNIFICANT DIFFERENCES (Squared Error Loss):")
print("-" * 60)

significant_pairs_squared = []
for pair in model_pairs:
    dm_stat = dm_results[pair]['Squared_Error']['DM_Statistic_Corrected']
    p_value = dm_results[pair]['Squared_Error']['P_Value_Two_Tailed_Corrected']
    if abs(dm_stat) > critical_value_two_tailed:  # Reject H₀
        model1, model2 = pair.split(" vs ")
        mean_diff = dm_results[pair]['Squared_Error']['Mean_Loss_Differential']
        
        if mean_diff > 0:
            better = model2
            worse = model1
        else:
            better = model1
            worse = model2
        
        significance = ""
        if p_value < 0.01:
            significance = "(p < 0.01)"
        else:
            significance = "(p < 0.05)"
        
        significant_pairs_squared.append((pair, better, worse, p_value, significance, dm_stat))
        print(f"  • {better} significantly better than {worse} {significance} |DM|={abs(dm_stat):.3f}")

if not significant_pairs_squared:
    print(f"  No significant differences found at α = 0.05 (|DM| > {critical_value_two_tailed:.3f})")

print("\nSIGNIFICANT DIFFERENCES (Absolute Error Loss):")
print("-" * 60)

significant_pairs_absolute = []
for pair in model_pairs:
    dm_stat = dm_results[pair]['Absolute_Error']['DM_Statistic_Corrected']
    p_value = dm_results[pair]['Absolute_Error']['P_Value_Two_Tailed_Corrected']
    if abs(dm_stat) > critical_value_two_tailed:  # Reject H₀
        model1, model2 = pair.split(" vs ")
        mean_diff = dm_results[pair]['Absolute_Error']['Mean_Loss_Differential']
        
        if mean_diff > 0:
            better = model2
            worse = model1
        else:
            better = model1
            worse = model2
        
        significance = ""
        if p_value < 0.01:
            significance = "(p < 0.01)"
        else:
            significance = "(p < 0.05)"
        
        significant_pairs_absolute.append((pair, better, worse, p_value, significance, dm_stat))
        print(f"  • {better} significantly better than {worse} {significance} |DM|={abs(dm_stat):.3f}")

if not significant_pairs_absolute:
    print(f"  No significant differences found at α = 0.05 (|DM| > {critical_value_two_tailed:.3f})")

# ============================================
# 7. RESIDUALS PLOT (ALL 6 MODELS)
# ============================================

print("\n" + "="*80)
print("RESIDUALS PLOT - ALL 6 MODELS")
print("="*80)

# Define color palette for models
model_colors = {
    'LSTM': 'blue',
    'XGBoost': 'green',
    'ARIMA': 'red',
    'ARIMA-LSTM': 'purple',
    'ARIMA-XGBoost': 'orange',
    'LSTM-XGBoost': 'brown'
}

# Define line styles for better differentiation
line_styles = {
    'LSTM': '-',
    'XGBoost': '-',
    'ARIMA': '-',
    'ARIMA-LSTM': '-',
    'ARIMA-XGBoost': '-',
    'LSTM-XGBoost': '-'
}

# Create figure
plt.figure(figsize=(15, 8))

# Plot each model's residuals
for model_name, residuals in residuals_dict.items():
    plt.plot(unified_df['Date'], residuals, 
             label=model_name, 
             color=model_colors[model_name],
             linestyle=line_styles[model_name],
             linewidth=2,
             alpha=0.8)

# Add zero reference line
plt.axhline(y=0, color='black', linestyle='-', linewidth=1, alpha=0.5, label='Zero Line')

# Add grid for better readability
plt.grid(True, alpha=0.3, linestyle='--')

# Customize plot
plt.xlabel('Date', fontsize=12)
plt.ylabel('Residuals', fontsize=12)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10, framealpha=0.9)

# Rotate date labels for better readability
plt.xticks(rotation=45)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Show plot
plt.show()

# ============================================
# 8. FINAL SUMMARY WITH CRITICAL VALUES
# ============================================

print("\n" + "="*80)
print("FINAL SUMMARY WITH CRITICAL VALUES (α = 0.05)")
print("="*80)

print("\n🏆 PERFORMANCE RANKING (Based on RMSE):")
print("-" * 40)
for i, (model_name, row) in enumerate(metrics_df.iterrows(), 1):
    print(f"{i}. {model_name}: RMSE = {row['RMSE']:.2f}, MAE = {row['MAE']:.2f}")

print("\n🔍 STATISTICALLY SIGNIFICANT FINDINGS (α = 0.05):")
print("-" * 40)

if significant_pairs_squared:
    print(f"Based on Squared Error Loss (MSE) - Critical value: |DM| > {critical_value_two_tailed:.3f}")
    for pair, better, worse, p_val, sig, dm_stat in significant_pairs_squared:
        print(f"  • {better} > {worse} {sig} (DM={dm_stat:.3f})")
else:
    print(f"No statistically significant differences found with squared error loss (|DM| > {critical_value_two_tailed:.3f})")

if significant_pairs_absolute:
    print(f"\nBased on Absolute Error Loss (MAE) - Critical value: |DM| > {critical_value_two_tailed:.3f}")
    for pair, better, worse, p_val, sig, dm_stat in significant_pairs_absolute:
        print(f"  • {better} > {worse} {sig} (DM={dm_stat:.3f})")
else:
    print(f"No statistically significant differences found with absolute error loss (|DM| > {critical_value_two_tailed:.3f})")

print("\n📊 DIEBOLD-MARIANO TEST INTERPRETATION:")
print("-" * 40)
print(f"1. Significance level: α = 0.05")
print(f"2. Critical values for rejection:")
print(f"   • Two-tailed test: |DM| > {critical_value_two_tailed:.3f}")
print(f"   • One-tailed test (right): DM > {critical_value_one_tailed:.3f}")
print(f"   • One-tailed test (left): DM < -{critical_value_one_tailed:.3f}")
print(f"3. *** indicates p < 0.01 (99% confidence)")
print(f"4. ** indicates p < 0.05 (95% confidence)")
print(f"5. No asterisk means not statistically significant")
print(f"6. 'Model A better than Model B' means Model A has significantly lower errors")

print("\n📈 DECISION RULES SUMMARY:")
print("-" * 40)
print("• For two-tailed test (H₁: models have different accuracy):")
print(f"  - Reject H₀ if |DM Statistic| > {critical_value_two_tailed:.3f}")
print("• For one-tailed test (H₁: model 2 is better than model 1):")
print(f"  - Reject H₀ if DM Statistic > {critical_value_one_tailed:.3f}")
print("• For one-tailed test (H₁: model 1 is better than model 2):")
print(f"  - Reject H₀ if DM Statistic < -{critical_value_one_tailed:.3f}")

print("\n" + "="*80)
print("ANALYSIS COMPLETE")
print("="*80)
# Out:
# ============================================================
# DIEBOLD-MARIANO TESTS (α = 0.05)
# ============================================================
# Loaded all prediction files:
# Total observations: 30
# Date range: 2018-11-15 to 2018-12-28
# Models: ['LSTM', 'XGBoost', 'ARIMA', 'ARIMA-LSTM', 'ARIMA-XGBoost', 'LSTM-XGBoost']
#
# ============================================================
# MODEL PERFORMANCE METRICS
# ============================================================
#
# Performance Metrics (sorted by RMSE):
# --------------------------------------------------------------------------------
#                   MSE    RMSE     MAE    MAPE  Mean_Residual  Std_Residual
# LSTM-XGBoost   2.0538  1.4331  1.2797  2.0690        -0.1376        1.4265
# XGBoost        2.4911  1.5783  1.2846  2.1063        -0.7852        1.3692
# LSTM           2.5760  1.6050  1.3328  2.1246         0.5099        1.5219
# ARIMA-XGBoost  2.7165  1.6482  1.3511  2.2156        -0.9087        1.3750
# ARIMA          2.7176  1.6485  1.3495  2.2127        -0.9063        1.3771
# ARIMA-LSTM     2.7202  1.6493  1.3513  2.2153        -0.9102        1.3754
#
# --------------------------------------------------------------------------------
# Best model by RMSE: LSTM-XGBoost (1.43)
# Worst model by RMSE: ARIMA-LSTM (1.65)
#
# ================================================================================
# DIEBOLD-MARIANO TESTS - MODEL COMPARISONS (α = 0.05)
# ================================================================================
#
# ================================================================================
# DIEBOLD-MARIANO TEST RESULTS (Squared Error Loss)
# ================================================================================
#
# H₀: The two models have equal predictive accuracy
# H₁: The two models have different predictive accuracy
# Significance level: α = 0.05
# Critical values: ±1.960 (two-tailed), 1.645 (one-tailed)
#
# DECISION RULE:
# - Reject H₀ if |DM Statistic| > 1.960 (two-tailed)
# - Reject H₀ if DM Statistic > 1.645 (model 2 better than model 1)
# - Reject H₀ if DM Statistic < -1.645 (model 1 better than model 2)
#
# Model Pair                DM Stat    P-Value      Sig.     Reject H₀?   Conclusion
# -----------------------------------------------------------------------------------------------------------
# LSTM-XGBoost vs XGBoost     -1.114      0.2651               NO      No significant difference
# LSTM-XGBoost vs LSTM        -1.150      0.2502               NO      No significant difference
# LSTM-XGBoost vs ARIMA-XGBoost   -1.619      0.1055               NO      No significant difference
# LSTM-XGBoost vs ARIMA       -1.631      0.1030               NO      No significant difference
# LSTM-XGBoost vs ARIMA-LSTM   -1.637      0.1016               NO      No significant difference
# XGBoost vs LSTM             -0.101      0.9194               NO      No significant difference
# XGBoost vs ARIMA-XGBoost    -1.841      0.0657               NO      No significant difference
# XGBoost vs ARIMA            -1.628      0.1036               NO      No significant difference
# XGBoost vs ARIMA-LSTM       -1.645      0.0999               NO      No significant difference
# LSTM vs ARIMA-XGBoost       -0.165      0.8686               NO      No significant difference
# LSTM vs ARIMA               -0.168      0.8669               NO      No significant difference
# LSTM vs ARIMA-LSTM          -0.171      0.8645               NO      No significant difference
# ARIMA-XGBoost vs ARIMA      -0.031      0.9751               NO      No significant difference
# ARIMA-XGBoost vs ARIMA-LSTM   -0.102      0.9191               NO      No significant difference
# ARIMA vs ARIMA-LSTM         -0.376      0.7068               NO      No significant difference
#
# ================================================================================
# DIEBOLD-MARIANO TEST RESULTS (Absolute Error Loss)
# ================================================================================
#
# H₀: The two models have equal predictive accuracy
# H₁: The two models have different predictive accuracy
# Significance level: α = 0.05
# Critical values: ±1.960 (two-tailed), 1.645 (one-tailed)
#
# DECISION RULE:
# - Reject H₀ if |DM Statistic| > 1.960 (two-tailed)
# - Reject H₀ if DM Statistic > 1.645 (model 2 better than model 1)
# - Reject H₀ if DM Statistic < -1.645 (model 1 better than model 2)
#
# Model Pair                DM Stat    P-Value      Sig.     Reject H₀?   Conclusion
# -----------------------------------------------------------------------------------------------------------
# LSTM-XGBoost vs XGBoost     -0.039      0.9687               NO      No significant difference
# LSTM-XGBoost vs LSTM        -0.416      0.6773               NO      No significant difference
# LSTM-XGBoost vs ARIMA-XGBoost   -0.546      0.5854               NO      No significant difference
# LSTM-XGBoost vs ARIMA       -0.534      0.5935               NO      No significant difference
# LSTM-XGBoost vs ARIMA-LSTM   -0.546      0.5849               NO      No significant difference
# XGBoost vs LSTM             -0.193      0.8469               NO      No significant difference
# XGBoost vs ARIMA-XGBoost    -1.450      0.1472               NO      No significant difference
# XGBoost vs ARIMA            -1.343      0.1793               NO      No significant difference
# XGBoost vs ARIMA-LSTM       -1.389      0.1650               NO      No significant difference
# LSTM vs ARIMA-XGBoost       -0.073      0.9420               NO      No significant difference
# LSTM vs ARIMA               -0.067      0.9468               NO      No significant difference
# LSTM vs ARIMA-LSTM          -0.074      0.9413               NO      No significant difference
# ARIMA-XGBoost vs ARIMA       0.204      0.8381               NO      No significant difference
# ARIMA-XGBoost vs ARIMA-LSTM   -0.023      0.9814               NO      No significant difference
# ARIMA vs ARIMA-LSTM         -0.721      0.4706               NO      No significant difference
#
# ================================================================================
# SUMMARY OF SIGNIFICANT DIFFERENCES (α = 0.05)
# ================================================================================
# Critical value for rejection: |DM| > 1.960
#
# SIGNIFICANT DIFFERENCES (Squared Error Loss):
# ------------------------------------------------------------
#   No significant differences found at α = 0.05 (|DM| > 1.960)
#
# SIGNIFICANT DIFFERENCES (Absolute Error Loss):
# ------------------------------------------------------------
#   No significant differences found at α = 0.05 (|DM| > 1.960)
#
# ================================================================================
# RESIDUALS PLOT - ALL 6 MODELS
# ================================================================================
# ================================================================================
# FINAL SUMMARY WITH CRITICAL VALUES (α = 0.05)
# ================================================================================
#
# 🏆 PERFORMANCE RANKING (Based on RMSE):
# ----------------------------------------
# 1. LSTM-XGBoost: RMSE = 1.43, MAE = 1.28
# 2. XGBoost: RMSE = 1.58, MAE = 1.28
# 3. LSTM: RMSE = 1.61, MAE = 1.33
# 4. ARIMA-XGBoost: RMSE = 1.65, MAE = 1.35
# 5. ARIMA: RMSE = 1.65, MAE = 1.35
# 6. ARIMA-LSTM: RMSE = 1.65, MAE = 1.35
#
# 🔍 STATISTICALLY SIGNIFICANT FINDINGS (α = 0.05):
# ----------------------------------------
# No statistically significant differences found with squared error loss (|DM| > 1.960)
# No statistically significant differences found with absolute error loss (|DM| > 1.960)
#
# 📊 DIEBOLD-MARIANO TEST INTERPRETATION:
# ----------------------------------------
# 1. Significance level: α = 0.05
# 2. Critical values for rejection:
#    • Two-tailed test: |DM| > 1.960
#    • One-tailed test (right): DM > 1.645
#    • One-tailed test (left): DM < -1.645
# 3. *** indicates p < 0.01 (99% confidence)
# 4. ** indicates p < 0.05 (95% confidence)
# 5. No asterisk means not statistically significant
# 6. 'Model A better than Model B' means Model A has significantly lower errors
#
# 📈 DECISION RULES SUMMARY:
# ----------------------------------------
# • For two-tailed test (H₁: models have different accuracy):
#   - Reject H₀ if |DM Statistic| > 1.960
# • For one-tailed test (H₁: model 2 is better than model 1):
#   - Reject H₀ if DM Statistic > 1.645
# • For one-tailed test (H₁: model 1 is better than model 2):
#   - Reject H₀ if DM Statistic < -1.645
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from typing import Dict
import warnings
warnings.filterwarnings('ignore')

# ============================================
# 1. LOAD ALL PREDICTION FILES
# ============================================

print("="*60)
print("DIEBOLD-MARIANO TESTS (MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ, α = 0.05)")
print("="*60)

# Load all CSV files
models_data = {
    'LSTM': pd.read_csv('lstm.csv', parse_dates=['Date']),
    'XGBoost': pd.read_csv('xgboost.csv', parse_dates=['Date']),
    'ARIMA': pd.read_csv('arima.csv', parse_dates=['Date']),
    'ARIMA-LSTM': pd.read_csv('arima_lstm.csv', parse_dates=['Date']),
    'ARIMA-XGBoost': pd.read_csv('arima_xgboost.csv', parse_dates=['Date']),
    'LSTM-XGBoost': pd.read_csv('lstm_xgboost.csv', parse_dates=['Date'])
}

# Standardize column names for consistency
for model_name, df in models_data.items():
    # Find the prediction column (non-Date, non-Actual)
    pred_col = [col for col in df.columns if col not in ['Date', 'Actual']][0]
    # Rename prediction column to standardized name
    df.rename(columns={pred_col: f'{model_name}_Predicted'}, inplace=True)

# Create a unified DataFrame with all predictions
unified_df = models_data['ARIMA'][['Date', 'Actual']].copy()

for model_name, df in models_data.items():
    pred_col = f'{model_name}_Predicted'
    unified_df[pred_col] = df[pred_col]

print("Loaded all prediction files:")
print(f"Total observations: {len(unified_df)}")
print(f"Date range: {unified_df['Date'].min().date()} to {unified_df['Date'].max().date()}")
print(f"Models: {list(models_data.keys())}")

# ============================================
# 2. CALCULATE RESIDUALS AND PERFORMANCE METRICS
# ============================================

print("\n" + "="*60)
print("MODEL PERFORMANCE METRICS")
print("="*60)

# Calculate residuals and performance metrics
metrics = {}
residuals_dict = {}

for model_name in models_data.keys():
    pred_col = f'{model_name}_Predicted'
    residuals = unified_df['Actual'] - unified_df[pred_col]
    residuals_dict[model_name] = residuals
    
    # Calculate metrics
    mse = np.mean(residuals**2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(residuals))
    mape = np.mean(np.abs(residuals / unified_df['Actual'])) * 100
    
    metrics[model_name] = {
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae,
        'MAPE': mape,
        'Mean_Residual': np.mean(residuals),
        'Std_Residual': np.std(residuals)
    }

# Create performance DataFrame
metrics_df = pd.DataFrame(metrics).T
metrics_df = metrics_df.sort_values('RMSE')

print("\nPerformance Metrics (sorted by RMSE):")
print("-" * 80)
print(metrics_df.round(4).to_string())
print("\n" + "-" * 80)
print(f"Best model by RMSE: {metrics_df.index[0]} ({metrics_df.iloc[0]['RMSE']:.2f})")
print(f"Worst model by RMSE: {metrics_df.index[-1]} ({metrics_df.iloc[-1]['RMSE']:.2f})")

# ============================================
# 3. DIEBOLD-MARIANO TEST IMPLEMENTATION (ΜΟΝΟΠΛΕΥΡΟΣ)
# ============================================

def diebold_mariano_test_one_sided(residuals1: pd.Series, residuals2: pd.Series, 
                                  h: int = 1, loss_type: str = 'squared') -> Dict:
    """
    Perform One-Sided Diebold-Mariano test for comparing two forecast models.
    
    Parameters:
    -----------
    residuals1 : pd.Series
        Residuals from model 1 (actual - predicted)
    residuals2 : pd.Series
        Residuals from model 2 (actual - predicted)
    h : int
        Forecast horizon (default=1 for one-step ahead)
    loss_type : str
        Loss function: 'squared' (MSE) or 'absolute' (MAE)
    
    Returns:
    --------
    dict : Test results including DM statistic and p-values
    """
    from scipy.stats import norm
    
    # Ensure equal length
    n = min(len(residuals1), len(residuals2))
    residuals1 = residuals1.iloc[:n]
    residuals2 = residuals2.iloc[:n]
    
    # Calculate loss differential
    if loss_type == 'squared':
        d = residuals1**2 - residuals2**2  # Positive: model1 worse than model2
    elif loss_type == 'absolute':
        d = np.abs(residuals1) - np.abs(residuals2)  # Positive: model1 worse than model2
    else:
        raise ValueError("loss_type must be 'squared' or 'absolute'")
    
    # Calculate mean and variance of loss differential
    mean_d = np.mean(d)
    var_d = np.var(d, ddof=1)  # Sample variance
    
    # Calculate DM statistic
    dm_stat = mean_d / np.sqrt(var_d / n)
    
    # Calculate p-values for ONE-SIDED test
    # H0: Models have equal predictive accuracy (mean_d = 0)
    # H1: Model 2 is BETTER than Model 1 (mean_d > 0)
    p_value_one_sided = 1 - norm.cdf(dm_stat)  # Right-tailed test
    
    # Bartlett's small-sample correction
    bartlett_factor = 1 + (h - 1) / n
    dm_stat_corrected = dm_stat / np.sqrt(bartlett_factor)
    p_value_one_sided_corrected = 1 - norm.cdf(dm_stat_corrected)
    
    return {
        'DM_Statistic': dm_stat,
        'DM_Statistic_Corrected': dm_stat_corrected,
        'P_Value_One_Sided': p_value_one_sided,
        'P_Value_One_Sided_Corrected': p_value_one_sided_corrected,
        'Mean_Loss_Differential': mean_d,
        'Std_Loss_Differential': np.sqrt(var_d),
        'Sample_Size': n,
        'Loss_Type': loss_type
    }

# ============================================
# 4. PERFORM PAIRWISE DIEBOLD-MARIANO TESTS (ΜΟΝΟΠΛΕΥΡΟΣ)
# ============================================

print("\n" + "="*80)
print("DIEBOLD-MARIANO TESTS - MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ (α = 0.05)")
print("="*80)

# Get model names in sorted order by RMSE (best to worst)
model_names_sorted = list(metrics_df.index)

# Perform pairwise DM tests
dm_results = {}
model_pairs = []

for i, model1 in enumerate(model_names_sorted):
    for model2 in model_names_sorted[i+1:]:
        pair_key = f"{model1} vs {model2}"
        model_pairs.append(pair_key)
        
        # Get residuals
        res1 = residuals_dict[model1]
        res2 = residuals_dict[model2]
        
        # Perform ONE-SIDED DM test with both loss functions
        dm_squared = diebold_mariano_test_one_sided(res1, res2, h=1, loss_type='squared')
        dm_absolute = diebold_mariano_test_one_sided(res1, res2, h=1, loss_type='absolute')
        
        dm_results[pair_key] = {
            'Squared_Error': dm_squared,
            'Absolute_Error': dm_absolute
        }

# ============================================
# 5. DISPLAY DM TEST RESULTS WITH CRITICAL VALUES (ΜΟΝΟΠΛΕΥΡΟΣ)
# ============================================

# Critical value for ONE-SIDED test at α = 0.05
critical_value_one_sided = norm.ppf(1 - 0.05)  # 1.645 for right-tailed test

print("\n" + "="*80)
print("DIEBOLD-MARIANO TEST RESULTS - MONOΠΛΕΥΡΟΣ (Squared Error Loss)")
print("="*80)
print("\nH₀: Τα δύο μοντέλα έχουν ίση προγνωστική ακρίβεια")
print("H₁: Το Model 2 είναι ΚΑΛΥΤΕΡΟ από το Model 1 (μικρότερο σφάλμα)")
print(f"Επίπεδο σημαντικότητας: α = 0.05")
print(f"Κρίσιμη τιμή: {critical_value_one_sided:.3f} (μονόπλευρος, δεξιόστροφος έλεγχος)")
print("\nΚΑΝΟΝΑΣ ΑΠΟΦΑΣΗΣ:")
print(f"- Απορρίπτουμε H₀ αν DM Statistic > {critical_value_one_sided:.3f}")
print(f"  (δηλαδή, το Model 2 είναι στατιστικά σημαντικά καλύτερο από το Model 1)")
print(f"- Δεν απορρίπτουμε H₀ αν DM Statistic ≤ {critical_value_one_sided:.3f}")
print("  (δεν υπάρχει στατιστικά σημαντική διαφορά υπέρ του Model 2)\n")

print(f"{'Model Pair':<25} {'DM Stat':<10} {'P-Value':<12} {'Reject H₀?':<12} {'Conclusion':<40}")
print("-" * 110)

for pair in model_pairs:
    dm_info = dm_results[pair]['Squared_Error']
    dm_stat = dm_info['DM_Statistic_Corrected']
    p_value = dm_info['P_Value_One_Sided_Corrected']
    
    # Determine if we reject H₀ (one-sided test)
    reject_h0 = "YES" if dm_stat > critical_value_one_sided else "NO"
    
    # Determine which model is better
    model1, model2 = pair.split(" vs ")
    
    # For ONE-SIDED test: H1 is that model2 is BETTER than model1
    # So if we reject H0, it means model2 is significantly better
    # If we don't reject H0, we cannot say model2 is better
    
    if reject_h0 == "YES":
        conclusion = f"{model2} is significantly better than {model1} (p = {p_value:.4f})"
    else:
        conclusion = f"No evidence that {model2} is better than {model1} (p = {p_value:.4f})"
    
    print(f"{pair:<25} {dm_stat:>8.3f} {p_value:>11.4f} {reject_h0:^12} {conclusion:<40}")

print("\n" + "="*80)
print("DIEBOLD-MARIANO TEST RESULTS - MONOΠΛΕΥΡΟΣ (Absolute Error Loss)")
print("="*80)
print("\nH₀: Τα δύο μοντέλα έχουν ίση προγνωστική ακρίβεια")
print("H₁: Το Model 2 είναι ΚΑΛΥΤΕΡΟ από το Model 1 (μικρότερο σφάλμα)")
print(f"Επίπεδο σημαντικότητας: α = 0.05")
print(f"Κρίσιμη τιμή: {critical_value_one_sided:.3f} (μονόπλευρος, δεξιόστροφος έλεγχος)")
print("\nΚΑΝΟΝΑΣ ΑΠΟΦΑΣΗΣ:")
print(f"- Απορρίπτουμε H₀ αν DM Statistic > {critical_value_one_sided:.3f}")
print(f"  (δηλαδή, το Model 2 είναι στατιστικά σημαντικά καλύτερο από το Model 1)")
print(f"- Δεν απορρίπτουμε H₀ αν DM Statistic ≤ {critical_value_one_sided:.3f}")
print("  (δεν υπάρχει στατιστικά σημαντική διαφορά υπέρ του Model 2)\n")

print(f"{'Model Pair':<25} {'DM Stat':<10} {'P-Value':<12} {'Reject H₀?':<12} {'Conclusion':<40}")
print("-" * 110)

for pair in model_pairs:
    dm_info = dm_results[pair]['Absolute_Error']
    dm_stat = dm_info['DM_Statistic_Corrected']
    p_value = dm_info['P_Value_One_Sided_Corrected']
    
    # Determine if we reject H₀ (one-sided test)
    reject_h0 = "YES" if dm_stat > critical_value_one_sided else "NO"
    
    # Determine which model is better
    model1, model2 = pair.split(" vs ")
    
    if reject_h0 == "YES":
        conclusion = f"{model2} is significantly better than {model1} (p = {p_value:.4f})"
    else:
        conclusion = f"No evidence that {model2} is better than {model1} (p = {p_value:.4f})"
    
    print(f"{pair:<25} {dm_stat:>8.3f} {p_value:>11.4f} {reject_h0:^12} {conclusion:<40}")

# ============================================
# 6. CREATE SUMMARY OF SIGNIFICANT DIFFERENCES (ΜΟΝΟΠΛΕΥΡΟΣ)
# ============================================

print("\n" + "="*80)
print("SUMMARY OF SIGNIFICANT DIFFERENCES - MONOΠΛΕΥΡΟΣ (α = 0.05)")
print("="*80)
print(f"Critical value for rejection: DM > {critical_value_one_sided:.3f}")
print("H1: Model 2 is BETTER than Model 1 (has smaller forecast errors)")

print("\nSIGNIFICANT DIFFERENCES - Model 2 better than Model 1 (Squared Error Loss):")
print("-" * 80)

significant_pairs_squared = []
for pair in model_pairs:
    dm_stat = dm_results[pair]['Squared_Error']['DM_Statistic_Corrected']
    p_value = dm_results[pair]['Squared_Error']['P_Value_One_Sided_Corrected']
    
    # For ONE-SIDED test: reject if DM > critical_value_one_sided
    if dm_stat > critical_value_one_sided:
        model1, model2 = pair.split(" vs ")
        
        significance_level = ""
        if p_value < 0.01:
            significance_level = "(p < 0.01)"
        else:
            significance_level = "(p < 0.05)"
        
        significant_pairs_squared.append((pair, model2, model1, p_value, significance_level, dm_stat))
        print(f"  • {model2} is significantly better than {model1} {significance_level} | DM = {dm_stat:.3f}")

if not significant_pairs_squared:
    print(f"  No significant differences found at α = 0.05 (DM > {critical_value_one_sided:.3f})")

print("\nSIGNIFICANT DIFFERENCES - Model 2 better than Model 1 (Absolute Error Loss):")
print("-" * 80)

significant_pairs_absolute = []
for pair in model_pairs:
    dm_stat = dm_results[pair]['Absolute_Error']['DM_Statistic_Corrected']
    p_value = dm_results[pair]['Absolute_Error']['P_Value_One_Sided_Corrected']
    
    # For ONE-SIDED test: reject if DM > critical_value_one_sided
    if dm_stat > critical_value_one_sided:
        model1, model2 = pair.split(" vs ")
        
        significance_level = ""
        if p_value < 0.01:
            significance_level = "(p < 0.01)"
        else:
            significance_level = "(p < 0.05)"
        
        significant_pairs_absolute.append((pair, model2, model1, p_value, significance_level, dm_stat))
        print(f"  • {model2} is significantly better than {model1} {significance_level} | DM = {dm_stat:.3f}")

if not significant_pairs_absolute:
    print(f"  No significant differences found at α = 0.05 (DM > {critical_value_one_sided:.3f})")

# ============================================
# 7. FINAL SUMMARY WITH CRITICAL VALUES (ΜΟΝΟΠΛΕΥΡΟΣ)
# ============================================

print("\n" + "="*80)
print("FINAL SUMMARY - MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ (α = 0.05)")
print("="*80)

print("\n🏆 PERFORMANCE RANKING (Based on RMSE):")
print("-" * 40)
for i, (model_name, row) in enumerate(metrics_df.iterrows(), 1):
    print(f"{i}. {model_name}: RMSE = {row['RMSE']:.2f}, MAE = {row['MAE']:.2f}")

print("\n🔍 STATISTICALLY SIGNIFICANT FINDINGS (ONE-SIDED TEST):")
print("-" * 40)
print("Hypothesis being tested: H1: Model 2 is BETTER than Model 1 (smaller errors)")

if significant_pairs_squared:
    print(f"\nBased on Squared Error Loss (MSE) - Critical value: DM > {critical_value_one_sided:.3f}")
    for pair, better, worse, p_val, sig, dm_stat in significant_pairs_squared:
        print(f"  • {better} > {worse} {sig} (DM = {dm_stat:.3f})")
else:
    print(f"\nNo statistically significant differences found with squared error loss (DM > {critical_value_one_sided:.3f})")

if significant_pairs_absolute:
    print(f"\nBased on Absolute Error Loss (MAE) - Critical value: DM > {critical_value_one_sided:.3f}")
    for pair, better, worse, p_val, sig, dm_stat in significant_pairs_absolute:
        print(f"  • {better} > {worse} {sig} (DM = {dm_stat:.3f})")
else:
    print(f"\nNo statistically significant differences found with absolute error loss (DM > {critical_value_one_sided:.3f})")

print("\n📊 MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ - ΕΡΜΗΝΕΙΑ:")
print("-" * 40)
print(f"1. Επίπεδο σημαντικότητας: α = 0.05")
print(f"2. Κρίσιμη τιμή: DM > {critical_value_one_sided:.3f}")
print(f"3. Υπόθεση H0: Τα μοντέλα έχουν ίση προγνωστική ακρίβεια")
print(f"4. Υπόθεση H1: Το Model 2 είναι ΚΑΛΥΤΕΡΟ από το Model 1")
print(f"5. Η p-τιμή υπολογίζεται ως: p = P(DM > dm_statistic | H0)")
print(f"6. Απορρίπτουμε H0 εάν: p < 0.05 ή DM > {critical_value_one_sided:.3f}")
print(f"7. Αν απορρίψουμε H0: Το Model 2 είναι στατιστικά σημαντικά καλύτερο")

print("\n⚠️ ΣΗΜΑΝΤΙΚΗ ΠΑΡΑΤΗΡΗΣΗ:")
print("-" * 40)
print("Ο μονόπλευρος έλεγχος ελέγχει ΜΟΝΟ αν το Model 2 είναι καλύτερο από το Model 1.")
print("Αν το Model 1 είναι καλύτερο, αυτό ΔΕΝ θα ανιχνευθεί από αυτόν τον έλεγχο.")
print("Για να ελέγξετε αν το Model 1 είναι καλύτερο, θα πρέπει να αντιστρέψετε τη σύγκριση.")
print("Εναλλακτικά, χρησιμοποιήστε δίπλευρο έλεγχο για να ελέγξετε για οποιαδήποτε διαφορά.")

print("\n" + "="*80)
print("ANALYSIS COMPLETE - MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ")
print("="*80)
# Out:
# ============================================================
# DIEBOLD-MARIANO TESTS (MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ, α = 0.05)
# ============================================================
# Loaded all prediction files:
# Total observations: 30
# Date range: 2018-11-15 to 2018-12-28
# Models: ['LSTM', 'XGBoost', 'ARIMA', 'ARIMA-LSTM', 'ARIMA-XGBoost', 'LSTM-XGBoost']
#
# ============================================================
# MODEL PERFORMANCE METRICS
# ============================================================
#
# Performance Metrics (sorted by RMSE):
# --------------------------------------------------------------------------------
#                   MSE    RMSE     MAE    MAPE  Mean_Residual  Std_Residual
# LSTM-XGBoost   2.0538  1.4331  1.2797  2.0690        -0.1376        1.4265
# XGBoost        2.4911  1.5783  1.2846  2.1063        -0.7852        1.3692
# LSTM           2.5760  1.6050  1.3328  2.1246         0.5099        1.5219
# ARIMA-XGBoost  2.7165  1.6482  1.3511  2.2156        -0.9087        1.3750
# ARIMA          2.7176  1.6485  1.3495  2.2127        -0.9063        1.3771
# ARIMA-LSTM     2.7202  1.6493  1.3513  2.2153        -0.9102        1.3754
#
# --------------------------------------------------------------------------------
# Best model by RMSE: LSTM-XGBoost (1.43)
# Worst model by RMSE: ARIMA-LSTM (1.65)
#
# ================================================================================
# DIEBOLD-MARIANO TESTS - MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ (α = 0.05)
# ================================================================================
#
# ================================================================================
# DIEBOLD-MARIANO TEST RESULTS - MONOΠΛΕΥΡΟΣ (Squared Error Loss)
# ================================================================================
#
# H₀: Τα δύο μοντέλα έχουν ίση προγνωστική ακρίβεια
# H₁: Το Model 2 είναι ΚΑΛΥΤΕΡΟ από το Model 1 (μικρότερο σφάλμα)
# Επίπεδο σημαντικότητας: α = 0.05
# Κρίσιμη τιμή: 1.645 (μονόπλευρος, δεξιόστροφος έλεγχος)
#
# ΚΑΝΟΝΑΣ ΑΠΟΦΑΣΗΣ:
# - Απορρίπτουμε H₀ αν DM Statistic > 1.645
#   (δηλαδή, το Model 2 είναι στατιστικά σημαντικά καλύτερο από το Model 1)
# - Δεν απορρίπτουμε H₀ αν DM Statistic ≤ 1.645
#   (δεν υπάρχει στατιστικά σημαντική διαφορά υπέρ του Model 2)
#
# Model Pair                DM Stat    P-Value      Reject H₀?   Conclusion
# --------------------------------------------------------------------------------------------------------------
# LSTM-XGBoost vs XGBoost     -1.114      0.8674      NO      No evidence that XGBoost is better than LSTM-XGBoost (p = 0.8674)
# LSTM-XGBoost vs LSTM        -1.150      0.8749      NO      No evidence that LSTM is better than LSTM-XGBoost (p = 0.8749)
# LSTM-XGBoost vs ARIMA-XGBoost   -1.619      0.9473      NO      No evidence that ARIMA-XGBoost is better than LSTM-XGBoost (p = 0.9473)
# LSTM-XGBoost vs ARIMA       -1.631      0.9485      NO      No evidence that ARIMA is better than LSTM-XGBoost (p = 0.9485)
# LSTM-XGBoost vs ARIMA-LSTM   -1.637      0.9492      NO      No evidence that ARIMA-LSTM is better than LSTM-XGBoost (p = 0.9492)
# XGBoost vs LSTM             -0.101      0.5403      NO      No evidence that LSTM is better than XGBoost (p = 0.5403)
# XGBoost vs ARIMA-XGBoost    -1.841      0.9672      NO      No evidence that ARIMA-XGBoost is better than XGBoost (p = 0.9672)
# XGBoost vs ARIMA            -1.628      0.9482      NO      No evidence that ARIMA is better than XGBoost (p = 0.9482)
# XGBoost vs ARIMA-LSTM       -1.645      0.9500      NO      No evidence that ARIMA-LSTM is better than XGBoost (p = 0.9500)
# LSTM vs ARIMA-XGBoost       -0.165      0.5657      NO      No evidence that ARIMA-XGBoost is better than LSTM (p = 0.5657)
# LSTM vs ARIMA               -0.168      0.5666      NO      No evidence that ARIMA is better than LSTM (p = 0.5666)
# LSTM vs ARIMA-LSTM          -0.171      0.5677      NO      No evidence that ARIMA-LSTM is better than LSTM (p = 0.5677)
# ARIMA-XGBoost vs ARIMA      -0.031      0.5124      NO      No evidence that ARIMA is better than ARIMA-XGBoost (p = 0.5124)
# ARIMA-XGBoost vs ARIMA-LSTM   -0.102      0.5405      NO      No evidence that ARIMA-LSTM is better than ARIMA-XGBoost (p = 0.5405)
# ARIMA vs ARIMA-LSTM         -0.376      0.6466      NO      No evidence that ARIMA-LSTM is better than ARIMA (p = 0.6466)
#
# ================================================================================
# DIEBOLD-MARIANO TEST RESULTS - MONOΠΛΕΥΡΟΣ (Absolute Error Loss)
# ================================================================================
#
# H₀: Τα δύο μοντέλα έχουν ίση προγνωστική ακρίβεια
# H₁: Το Model 2 είναι ΚΑΛΥΤΕΡΟ από το Model 1 (μικρότερο σφάλμα)
# Επίπεδο σημαντικότητας: α = 0.05
# Κρίσιμη τιμή: 1.645 (μονόπλευρος, δεξιόστροφος έλεγχος)
#
# ΚΑΝΟΝΑΣ ΑΠΟΦΑΣΗΣ:
# - Απορρίπτουμε H₀ αν DM Statistic > 1.645
#   (δηλαδή, το Model 2 είναι στατιστικά σημαντικά καλύτερο από το Model 1)
# - Δεν απορρίπτουμε H₀ αν DM Statistic ≤ 1.645
#   (δεν υπάρχει στατιστικά σημαντική διαφορά υπέρ του Model 2)
#
# Model Pair                DM Stat    P-Value      Reject H₀?   Conclusion
# --------------------------------------------------------------------------------------------------------------
# LSTM-XGBoost vs XGBoost     -0.039      0.5157      NO      No evidence that XGBoost is better than LSTM-XGBoost (p = 0.5157)
# LSTM-XGBoost vs LSTM        -0.416      0.6614      NO      No evidence that LSTM is better than LSTM-XGBoost (p = 0.6614)
# LSTM-XGBoost vs ARIMA-XGBoost   -0.546      0.7073      NO      No evidence that ARIMA-XGBoost is better than LSTM-XGBoost (p = 0.7073)
# LSTM-XGBoost vs ARIMA       -0.534      0.7032      NO      No evidence that ARIMA is better than LSTM-XGBoost (p = 0.7032)
# LSTM-XGBoost vs ARIMA-LSTM   -0.546      0.7076      NO      No evidence that ARIMA-LSTM is better than LSTM-XGBoost (p = 0.7076)
# XGBoost vs LSTM             -0.193      0.5765      NO      No evidence that LSTM is better than XGBoost (p = 0.5765)
# XGBoost vs ARIMA-XGBoost    -1.450      0.9264      NO      No evidence that ARIMA-XGBoost is better than XGBoost (p = 0.9264)
# XGBoost vs ARIMA            -1.343      0.9104      NO      No evidence that ARIMA is better than XGBoost (p = 0.9104)
# XGBoost vs ARIMA-LSTM       -1.389      0.9175      NO      No evidence that ARIMA-LSTM is better than XGBoost (p = 0.9175)
# LSTM vs ARIMA-XGBoost       -0.073      0.5290      NO      No evidence that ARIMA-XGBoost is better than LSTM (p = 0.5290)
# LSTM vs ARIMA               -0.067      0.5266      NO      No evidence that ARIMA is better than LSTM (p = 0.5266)
# LSTM vs ARIMA-LSTM          -0.074      0.5293      NO      No evidence that ARIMA-LSTM is better than LSTM (p = 0.5293)
# ARIMA-XGBoost vs ARIMA       0.204      0.4190      NO      No evidence that ARIMA is better than ARIMA-XGBoost (p = 0.4190)
# ARIMA-XGBoost vs ARIMA-LSTM   -0.023      0.5093      NO      No evidence that ARIMA-LSTM is better than ARIMA-XGBoost (p = 0.5093)
# ARIMA vs ARIMA-LSTM         -0.721      0.7647      NO      No evidence that ARIMA-LSTM is better than ARIMA (p = 0.7647)
#
# ================================================================================
# SUMMARY OF SIGNIFICANT DIFFERENCES - MONOΠΛΕΥΡΟΣ (α = 0.05)
# ================================================================================
# Critical value for rejection: DM > 1.645
# H1: Model 2 is BETTER than Model 1 (has smaller forecast errors)
#
# SIGNIFICANT DIFFERENCES - Model 2 better than Model 1 (Squared Error Loss):
# --------------------------------------------------------------------------------
#   No significant differences found at α = 0.05 (DM > 1.645)
#
# SIGNIFICANT DIFFERENCES - Model 2 better than Model 1 (Absolute Error Loss):
# --------------------------------------------------------------------------------
#   No significant differences found at α = 0.05 (DM > 1.645)
#
# ================================================================================
# FINAL SUMMARY - MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ (α = 0.05)
# ================================================================================
#
# 🏆 PERFORMANCE RANKING (Based on RMSE):
# ----------------------------------------
# 1. LSTM-XGBoost: RMSE = 1.43, MAE = 1.28
# 2. XGBoost: RMSE = 1.58, MAE = 1.28
# 3. LSTM: RMSE = 1.61, MAE = 1.33
# 4. ARIMA-XGBoost: RMSE = 1.65, MAE = 1.35
# 5. ARIMA: RMSE = 1.65, MAE = 1.35
# 6. ARIMA-LSTM: RMSE = 1.65, MAE = 1.35
#
# 🔍 STATISTICALLY SIGNIFICANT FINDINGS (ONE-SIDED TEST):
# ----------------------------------------
# Hypothesis being tested: H1: Model 2 is BETTER than Model 1 (smaller errors)
#
# No statistically significant differences found with squared error loss (DM > 1.645)
#
# No statistically significant differences found with absolute error loss (DM > 1.645)
#
# 📊 MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ - ΕΡΜΗΝΕΙΑ:
# ----------------------------------------
# 1. Επίπεδο σημαντικότητας: α = 0.05
# 2. Κρίσιμη τιμή: DM > 1.645
# 3. Υπόθεση H0: Τα μοντέλα έχουν ίση προγνωστική ακρίβεια
# 4. Υπόθεση H1: Το Model 2 είναι ΚΑΛΥΤΕΡΟ από το Model 1
# 5. Η p-τιμή υπολογίζεται ως: p = P(DM > dm_statistic | H0)
# 6. Απορρίπτουμε H0 εάν: p < 0.05 ή DM > 1.645
# 7. Αν απορρίψουμε H0: Το Model 2 είναι στατιστικά σημαντικά καλύτερο
#
# ⚠️ ΣΗΜΑΝΤΙΚΗ ΠΑΡΑΤΗΡΗΣΗ:
# ----------------------------------------
# Ο μονόπλευρος έλεγχος ελέγχει ΜΟΝΟ αν το Model 2 είναι καλύτερο από το Model 1.
# Αν το Model 1 είναι καλύτερο, αυτό ΔΕΝ θα ανιχνευθεί από αυτόν τον έλεγχο.
# Για να ελέγξετε αν το Model 1 είναι καλύτερο, θα πρέπει να αντιστρέψετε τη σύγκριση.
# Εναλλακτικά, χρησιμοποιήστε δίπλευρο έλεγχο για να ελέγξετε για οποιαδήποτε διαφορά.
#
# ================================================================================
# ANALYSIS COMPLETE - MONOΠΛΕΥΡΟΣ ΈΛΕΓΧΟΣ
# ================================================================================
