# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from typing import Dict
import warnings
warnings.filterwarnings('ignore')

# ============================================
# 1. LOAD ALL PREDICTION FILES
# ============================================

print("="*60)
print("DIEBOLD-MARIANO TESTS (α = 0.05)")
print("="*60)

# Load all CSV files
models_data = {
    'LSTM': pd.read_csv('lstm.csv', parse_dates=['Date']),
    'XGBoost': pd.read_csv('xgboost.csv', parse_dates=['Date']),
    'ARIMA': pd.read_csv('arima.csv', parse_dates=['Date']),
    'ARIMA-LSTM': pd.read_csv('arima_lstm.csv', parse_dates=['Date']),
    'ARIMA-XGBoost': pd.read_csv('arima_xgboost.csv', parse_dates=['Date']),
    'LSTM-XGBoost': pd.read_csv('lstm_xgboost.csv', parse_dates=['Date'])
}

# Standardize column names for consistency
for model_name, df in models_data.items():
    # Find the prediction column (non-Date, non-Actual)
    pred_col = [col for col in df.columns if col not in ['Date', 'Actual']][0]
    # Rename prediction column to standardized name
    df.rename(columns={pred_col: f'{model_name}_Predicted'}, inplace=True)

# Create a unified DataFrame with all predictions
unified_df = models_data['ARIMA'][['Date', 'Actual']].copy()

for model_name, df in models_data.items():
    pred_col = f'{model_name}_Predicted'
    unified_df[pred_col] = df[pred_col]

print("Loaded all prediction files:")
print(f"Total observations: {len(unified_df)}")
print(f"Date range: {unified_df['Date'].min().date()} to {unified_df['Date'].max().date()}")
print(f"Models: {list(models_data.keys())}")

# ============================================
# 2. CALCULATE RESIDUALS AND PERFORMANCE METRICS
# ============================================

print("\n" + "="*60)
print("MODEL PERFORMANCE METRICS")
print("="*60)

# Calculate residuals and performance metrics
metrics = {}
residuals_dict = {}

for model_name in models_data.keys():
    pred_col = f'{model_name}_Predicted'
    residuals = unified_df['Actual'] - unified_df[pred_col]
    residuals_dict[model_name] = residuals
    
    # Calculate metrics
    mse = np.mean(residuals**2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(residuals))
    mape = np.mean(np.abs(residuals / unified_df['Actual'])) * 100
    
    metrics[model_name] = {
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae,
        'MAPE': mape,
        'Mean_Residual': np.mean(residuals),
        'Std_Residual': np.std(residuals)
    }

# Create performance DataFrame
metrics_df = pd.DataFrame(metrics).T
metrics_df = metrics_df.sort_values('RMSE')

print("\nPerformance Metrics (sorted by RMSE):")
print("-" * 80)
print(metrics_df.round(4).to_string())
print("\n" + "-" * 80)
print(f"Best model by RMSE: {metrics_df.index[0]} ({metrics_df.iloc[0]['RMSE']:.2f})")
print(f"Worst model by RMSE: {metrics_df.index[-1]} ({metrics_df.iloc[-1]['RMSE']:.2f})")

# ============================================
# 3. DIEBOLD-MARIANO TEST IMPLEMENTATION (α = 0.05)
# ============================================

def diebold_mariano_test(residuals1: pd.Series, residuals2: pd.Series, 
                        h: int = 1, loss_type: str = 'squared') -> Dict:
    """
    Perform Diebold-Mariano test for comparing two forecast models.
    
    Parameters:
    -----------
    residuals1 : pd.Series
        Residuals from model 1 (actual - predicted)
    residuals2 : pd.Series
        Residuals from model 2 (actual - predicted)
    h : int
        Forecast horizon (default=1 for one-step ahead)
    loss_type : str
        Loss function: 'squared' (MSE) or 'absolute' (MAE)
    
    Returns:
    --------
    dict : Test results including DM statistic and p-values
    """
    from scipy.stats import norm
    
    # Ensure equal length
    n = min(len(residuals1), len(residuals2))
    residuals1 = residuals1.iloc[:n]
    residuals2 = residuals2.iloc[:n]
    
    # Calculate loss differential
    if loss_type == 'squared':
        d = residuals1**2 - residuals2**2
    elif loss_type == 'absolute':
        d = np.abs(residuals1) - np.abs(residuals2)
    else:
        raise ValueError("loss_type must be 'squared' or 'absolute'")
    
    # Calculate mean and variance of loss differential
    mean_d = np.mean(d)
    var_d = np.var(d, ddof=1)  # Sample variance
    
    # Calculate DM statistic
    dm_stat = mean_d / np.sqrt(var_d / n)
    
    # Calculate p-values (two-tailed test)
    p_value_two_tailed = 2 * (1 - norm.cdf(abs(dm_stat)))
    p_value_one_tailed_better = 1 - norm.cdf(dm_stat)  # H1: model2 better than model1
    p_value_one_tailed_worse = norm.cdf(dm_stat)       # H1: model2 worse than model1
    
    # Bartlett's small-sample correction
    bartlett_factor = 1 + (h - 1) / n
    dm_stat_corrected = dm_stat / np.sqrt(bartlett_factor)
    p_value_two_tailed_corrected = 2 * (1 - norm.cdf(abs(dm_stat_corrected)))
    
    return {
        'DM_Statistic': dm_stat,
        'DM_Statistic_Corrected': dm_stat_corrected,
        'P_Value_Two_Tailed': p_value_two_tailed,
        'P_Value_Two_Tailed_Corrected': p_value_two_tailed_corrected,
        'P_Value_One_Tailed_Better': p_value_one_tailed_better,
        'P_Value_One_Tailed_Worse': p_value_one_tailed_worse,
        'Mean_Loss_Differential': mean_d,
        'Std_Loss_Differential': np.sqrt(var_d),
        'Sample_Size': n,
        'Loss_Type': loss_type
    }

# ============================================
# 4. PERFORM PAIRWISE DIEBOLD-MARIANO TESTS (α = 0.05)
# ============================================

print("\n" + "="*80)
print("DIEBOLD-MARIANO TESTS - MODEL COMPARISONS (α = 0.05)")
print("="*80)

# Get model names in sorted order by RMSE (best to worst)
model_names_sorted = list(metrics_df.index)

# Perform pairwise DM tests
dm_results = {}
model_pairs = []

for i, model1 in enumerate(model_names_sorted):
    for model2 in model_names_sorted[i+1:]:
        pair_key = f"{model1} vs {model2}"
        model_pairs.append(pair_key)
        
        # Get residuals
        res1 = residuals_dict[model1]
        res2 = residuals_dict[model2]
        
        # Perform DM test with both loss functions
        dm_squared = diebold_mariano_test(res1, res2, h=1, loss_type='squared')
        dm_absolute = diebold_mariano_test(res1, res2, h=1, loss_type='absolute')
        
        dm_results[pair_key] = {
            'Squared_Error': dm_squared,
            'Absolute_Error': dm_absolute
        }

# ============================================
# 5. DISPLAY DM TEST RESULTS WITH α = 0.05
# ============================================

print("\nDIEBOLD-MARIANO TEST RESULTS (Squared Error Loss)")
print("="*80)
print("\nH₀: The two models have equal predictive accuracy")
print("H₁: The two models have different predictive accuracy")
print(f"Significance level: α = 0.05\n")

print(f"{'Model Pair':<25} {'DM Stat':<10} {'P-Value':<12} {'Sig.':<8} {'Conclusion':<30}")
print("-" * 85)

for pair in model_pairs:
    dm_info = dm_results[pair]['Squared_Error']
    dm_stat = dm_info['DM_Statistic_Corrected']
    p_value = dm_info['P_Value_Two_Tailed_Corrected']
    
    # Determine significance (α = 0.05)
    if p_value < 0.01:
        sig = "***"
    elif p_value < 0.05:
        sig = "**"
    else:
        sig = ""
    
    # Determine which model is better
    model1, model2 = pair.split(" vs ")
    mean_diff = dm_info['Mean_Loss_Differential']
    
    if mean_diff > 0:
        # Model1 has higher loss (worse) than Model2
        better_model = model2
        worse_model = model1
        conclusion = f"{model2} better than {model1}"
    else:
        # Model1 has lower loss (better) than Model2
        better_model = model1
        worse_model = model2
        conclusion = f"{model1} better than {model2}"
    
    # Only show conclusion if significant at 5% level (α = 0.05)
    if p_value >= 0.05:
        conclusion = "No significant difference"
    
    print(f"{pair:<25} {dm_stat:>8.3f} {p_value:>11.4f} {sig:^8} {conclusion:<30}")

print("\n" + "="*80)
print("DIEBOLD-MARIANO TEST RESULTS (Absolute Error Loss)")
print("="*80)
print("\nH₀: The two models have equal predictive accuracy")
print("H₁: The two models have different predictive accuracy")
print(f"Significance level: α = 0.05\n")

print(f"{'Model Pair':<25} {'DM Stat':<10} {'P-Value':<12} {'Sig.':<8} {'Conclusion':<30}")
print("-" * 85)

for pair in model_pairs:
    dm_info = dm_results[pair]['Absolute_Error']
    dm_stat = dm_info['DM_Statistic_Corrected']
    p_value = dm_info['P_Value_Two_Tailed_Corrected']
    
    # Determine significance (α = 0.05)
    if p_value < 0.01:
        sig = "***"
    elif p_value < 0.05:
        sig = "**"
    else:
        sig = ""
    
    # Determine which model is better
    model1, model2 = pair.split(" vs ")
    mean_diff = dm_info['Mean_Loss_Differential']
    
    if mean_diff > 0:
        # Model1 has higher loss (worse) than Model2
        better_model = model2
        worse_model = model1
        conclusion = f"{model2} better than {model1}"
    else:
        # Model1 has lower loss (better) than Model2
        better_model = model1
        worse_model = model2
        conclusion = f"{model1} better than {model2}"
    
    # Only show conclusion if significant at 5% level (α = 0.05)
    if p_value >= 0.05:
        conclusion = "No significant difference"
    
    print(f"{pair:<25} {dm_stat:>8.3f} {p_value:>11.4f} {sig:^8} {conclusion:<30}")

# ============================================
# 6. CREATE SUMMARY OF SIGNIFICANT DIFFERENCES (α = 0.05)
# ============================================

print("\n" + "="*80)
print("SUMMARY OF SIGNIFICANT DIFFERENCES (α = 0.05)")
print("="*80)

print("\nSIGNIFICANT DIFFERENCES (Squared Error Loss):")
print("-" * 60)

significant_pairs_squared = []
for pair in model_pairs:
    p_value = dm_results[pair]['Squared_Error']['P_Value_Two_Tailed_Corrected']
    if p_value < 0.05:  # CHANGED: α = 0.05
        model1, model2 = pair.split(" vs ")
        mean_diff = dm_results[pair]['Squared_Error']['Mean_Loss_Differential']
        
        if mean_diff > 0:
            better = model2
            worse = model1
        else:
            better = model1
            worse = model2
        
        significance = ""
        if p_value < 0.01:
            significance = "(p < 0.01)"
        else:
            significance = "(p < 0.05)"
        
        significant_pairs_squared.append((pair, better, worse, p_value, significance))
        print(f"  • {better} significantly better than {worse} {significance}")

if not significant_pairs_squared:
    print("  No significant differences found at α = 0.05")

print("\nSIGNIFICANT DIFFERENCES (Absolute Error Loss):")
print("-" * 60)

significant_pairs_absolute = []
for pair in model_pairs:
    p_value = dm_results[pair]['Absolute_Error']['P_Value_Two_Tailed_Corrected']
    if p_value < 0.05:  # CHANGED: α = 0.05
        model1, model2 = pair.split(" vs ")
        mean_diff = dm_results[pair]['Absolute_Error']['Mean_Loss_Differential']
        
        if mean_diff > 0:
            better = model2
            worse = model1
        else:
            better = model1
            worse = model2
        
        significance = ""
        if p_value < 0.01:
            significance = "(p < 0.01)"
        else:
            significance = "(p < 0.05)"
        
        significant_pairs_absolute.append((pair, better, worse, p_value, significance))
        print(f"  • {better} significantly better than {worse} {significance}")

if not significant_pairs_absolute:
    print("  No significant differences found at α = 0.05")

# ============================================
# 7. RESIDUALS PLOT (ALL 6 MODELS)
# ============================================

print("\n" + "="*80)
print("RESIDUALS PLOT - ALL 6 MODELS")
print("="*80)

# Define color palette for models
model_colors = {
    'LSTM': 'blue',
    'XGBoost': 'green',
    'ARIMA': 'red',
    'ARIMA-LSTM': 'purple',
    'ARIMA-XGBoost': 'orange',
    'LSTM-XGBoost': 'brown'
}

# Define line styles for better differentiation
line_styles = {
    'LSTM': '-',
    'XGBoost': '-',
    'ARIMA': '-',
    'ARIMA-LSTM': '-',
    'ARIMA-XGBoost': '-',
    'LSTM-XGBoost': '-'
}

# Create figure
plt.figure(figsize=(15, 8))

# Plot each model's residuals
for model_name, residuals in residuals_dict.items():
    plt.plot(unified_df['Date'], residuals, 
             label=model_name, 
             color=model_colors[model_name],
             linestyle=line_styles[model_name],
             linewidth=2,
             alpha=0.8)

# Add zero reference line
plt.axhline(y=0, color='black', linestyle='-', linewidth=1, alpha=0.5, label='Zero Line')

# Add grid for better readability
plt.grid(True, alpha=0.3, linestyle='--')

# Customize plot
plt.xlabel('Date', fontsize=12)
plt.ylabel('Residuals', fontsize=12)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10, framealpha=0.9)

# Rotate date labels for better readability
plt.xticks(rotation=45)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Show plot
plt.show()

# ============================================
# 8. FINAL SUMMARY WITH α = 0.05
# ============================================

print("\n" + "="*80)
print("FINAL SUMMARY (α = 0.05)")
print("="*80)

print("\n🏆 PERFORMANCE RANKING (Based on RMSE):")
print("-" * 40)
for i, (model_name, row) in enumerate(metrics_df.iterrows(), 1):
    print(f"{i}. {model_name}: RMSE = {row['RMSE']:.2f}, MAE = {row['MAE']:.2f}")

print("\n🔍 STATISTICALLY SIGNIFICANT FINDINGS (α = 0.05):")
print("-" * 40)

if significant_pairs_squared:
    print("Based on Squared Error Loss (MSE):")
    for pair, better, worse, p_val, sig in significant_pairs_squared:
        print(f"  • {better} > {worse} {sig}")
else:
    print("No statistically significant differences found with squared error loss")

if significant_pairs_absolute:
    print("\nBased on Absolute Error Loss (MAE):")
    for pair, better, worse, p_val, sig in significant_pairs_absolute:
        print(f"  • {better} > {worse} {sig}")
else:
    print("No statistically significant differences found with absolute error loss")

print("\n📊 INTERPRETATION:")
print("-" * 40)
print("1. Significance level α = 0.05 means we require 95% confidence")
print("2. *** indicates p < 0.01 (99% confidence)")
print("3. ** indicates p < 0.05 (95% confidence)")
print("4. No asterisk means not statistically significant")
print("5. 'Model A better than Model B' means Model A has significantly lower errors")

print("\n" + "="*80)
print("ANALYSIS COMPLETE")
print("="*80)
# Out:
# ============================================================
# DIEBOLD-MARIANO TESTS (α = 0.05)
# ============================================================
# Loaded all prediction files:
# Total observations: 30
# Date range: 2025-08-29 to 2025-10-09
# Models: ['LSTM', 'XGBoost', 'ARIMA', 'ARIMA-LSTM', 'ARIMA-XGBoost', 'LSTM-XGBoost']
#
# ============================================================
# MODEL PERFORMANCE METRICS
# ============================================================
#
# Performance Metrics (sorted by RMSE):
# --------------------------------------------------------------------------------
#                    MSE    RMSE     MAE    MAPE  Mean_Residual  Std_Residual
# ARIMA-XGBoost   5.3523  2.3135  1.6244  0.8224        -0.2222        2.3028
# ARIMA           5.3675  2.3168  1.6141  0.8171        -0.1942        2.3086
# ARIMA-LSTM      5.4646  2.3377  1.6301  0.8253        -0.2210        2.3272
# XGBoost         9.8652  3.1409  2.8006  1.4199        -1.1846        2.9089
# LSTM-XGBoost   13.9165  3.7305  3.2720  1.6550         0.4493        3.7033
# LSTM           47.9918  6.9276  5.8420  2.9651         2.0832        6.6070
#
# --------------------------------------------------------------------------------
# Best model by RMSE: ARIMA-XGBoost (2.31)
# Worst model by RMSE: LSTM (6.93)
#
# ================================================================================
# DIEBOLD-MARIANO TESTS - MODEL COMPARISONS (α = 0.05)
# ================================================================================
#
# DIEBOLD-MARIANO TEST RESULTS (Squared Error Loss)
# ================================================================================
#
# H₀: The two models have equal predictive accuracy
# H₁: The two models have different predictive accuracy
# Significance level: α = 0.05
#
# Model Pair                DM Stat    P-Value      Sig.     Conclusion
# -------------------------------------------------------------------------------------
# ARIMA-XGBoost vs ARIMA      -0.157      0.8750          No significant difference
# ARIMA-XGBoost vs ARIMA-LSTM   -1.167      0.2431          No significant difference
# ARIMA-XGBoost vs XGBoost    -2.217      0.0266    **    ARIMA-XGBoost better than XGBoost
# ARIMA-XGBoost vs LSTM-XGBoost   -3.050      0.0023   ***    ARIMA-XGBoost better than LSTM-XGBoost
# ARIMA-XGBoost vs LSTM       -4.437      0.0000   ***    ARIMA-XGBoost better than LSTM
# ARIMA vs ARIMA-LSTM         -2.706      0.0068   ***    ARIMA better than ARIMA-LSTM
# ARIMA vs XGBoost            -2.200      0.0278    **    ARIMA better than XGBoost
# ARIMA vs LSTM-XGBoost       -3.035      0.0024   ***    ARIMA better than LSTM-XGBoost
# ARIMA vs LSTM               -4.429      0.0000   ***    ARIMA better than LSTM
# ARIMA-LSTM vs XGBoost       -2.137      0.0326    **    ARIMA-LSTM better than XGBoost
# ARIMA-LSTM vs LSTM-XGBoost   -2.986      0.0028   ***    ARIMA-LSTM better than LSTM-XGBoost
# ARIMA-LSTM vs LSTM          -4.418      0.0000   ***    ARIMA-LSTM better than LSTM
# XGBoost vs LSTM-XGBoost     -1.398      0.1623          No significant difference
# XGBoost vs LSTM             -3.907      0.0001   ***    XGBoost better than LSTM
# LSTM-XGBoost vs LSTM        -4.166      0.0000   ***    LSTM-XGBoost better than LSTM
#
# ================================================================================
# DIEBOLD-MARIANO TEST RESULTS (Absolute Error Loss)
# ================================================================================
#
# H₀: The two models have equal predictive accuracy
# H₁: The two models have different predictive accuracy
# Significance level: α = 0.05
#
# Model Pair                DM Stat    P-Value      Sig.     Conclusion
# -------------------------------------------------------------------------------------
# ARIMA-XGBoost vs ARIMA       0.445      0.6560          No significant difference
# ARIMA-XGBoost vs ARIMA-LSTM   -0.227      0.8202          No significant difference
# ARIMA-XGBoost vs XGBoost    -4.124      0.0000   ***    ARIMA-XGBoost better than XGBoost
# ARIMA-XGBoost vs LSTM-XGBoost   -3.559      0.0004   ***    ARIMA-XGBoost better than LSTM-XGBoost
# ARIMA-XGBoost vs LSTM       -5.654      0.0000   ***    ARIMA-XGBoost better than LSTM
# ARIMA vs ARIMA-LSTM         -1.512      0.1306          No significant difference
# ARIMA vs XGBoost            -4.090      0.0000   ***    ARIMA better than XGBoost
# ARIMA vs LSTM-XGBoost       -3.552      0.0004   ***    ARIMA better than LSTM-XGBoost
# ARIMA vs LSTM               -5.658      0.0000   ***    ARIMA better than LSTM
# ARIMA-LSTM vs XGBoost       -4.054      0.0001   ***    ARIMA-LSTM better than XGBoost
# ARIMA-LSTM vs LSTM-XGBoost   -3.520      0.0004   ***    ARIMA-LSTM better than LSTM-XGBoost
# ARIMA-LSTM vs LSTM          -5.637      0.0000   ***    ARIMA-LSTM better than LSTM
# XGBoost vs LSTM-XGBoost     -1.099      0.2719          No significant difference
# XGBoost vs LSTM             -4.238      0.0000   ***    XGBoost better than LSTM
# LSTM-XGBoost vs LSTM        -4.875      0.0000   ***    LSTM-XGBoost better than LSTM
#
# ================================================================================
# SUMMARY OF SIGNIFICANT DIFFERENCES (α = 0.05)
# ================================================================================
#
# SIGNIFICANT DIFFERENCES (Squared Error Loss):
# ------------------------------------------------------------
#   • ARIMA-XGBoost significantly better than XGBoost (p < 0.05)
#   • ARIMA-XGBoost significantly better than LSTM-XGBoost (p < 0.01)
#   • ARIMA-XGBoost significantly better than LSTM (p < 0.01)
#   • ARIMA significantly better than ARIMA-LSTM (p < 0.01)
#   • ARIMA significantly better than XGBoost (p < 0.05)
#   • ARIMA significantly better than LSTM-XGBoost (p < 0.01)
#   • ARIMA significantly better than LSTM (p < 0.01)
#   • ARIMA-LSTM significantly better than XGBoost (p < 0.05)
#   • ARIMA-LSTM significantly better than LSTM-XGBoost (p < 0.01)
#   • ARIMA-LSTM significantly better than LSTM (p < 0.01)
#   • XGBoost significantly better than LSTM (p < 0.01)
#   • LSTM-XGBoost significantly better than LSTM (p < 0.01)
#
# SIGNIFICANT DIFFERENCES (Absolute Error Loss):
# ------------------------------------------------------------
#   • ARIMA-XGBoost significantly better than XGBoost (p < 0.01)
#   • ARIMA-XGBoost significantly better than LSTM-XGBoost (p < 0.01)
#   • ARIMA-XGBoost significantly better than LSTM (p < 0.01)
#   • ARIMA significantly better than XGBoost (p < 0.01)
#   • ARIMA significantly better than LSTM-XGBoost (p < 0.01)
#   • ARIMA significantly better than LSTM (p < 0.01)
#   • ARIMA-LSTM significantly better than XGBoost (p < 0.01)
#   • ARIMA-LSTM significantly better than LSTM-XGBoost (p < 0.01)
#   • ARIMA-LSTM significantly better than LSTM (p < 0.01)
#   • XGBoost significantly better than LSTM (p < 0.01)
#   • LSTM-XGBoost significantly better than LSTM (p < 0.01)
#
# ================================================================================
# RESIDUALS PLOT - ALL 6 MODELS
# ================================================================================
# ================================================================================
# FINAL SUMMARY (α = 0.05)
# ================================================================================
#
# 🏆 PERFORMANCE RANKING (Based on RMSE):
# ----------------------------------------
# 1. ARIMA-XGBoost: RMSE = 2.31, MAE = 1.62
# 2. ARIMA: RMSE = 2.32, MAE = 1.61
# 3. ARIMA-LSTM: RMSE = 2.34, MAE = 1.63
# 4. XGBoost: RMSE = 3.14, MAE = 2.80
# 5. LSTM-XGBoost: RMSE = 3.73, MAE = 3.27
# 6. LSTM: RMSE = 6.93, MAE = 5.84
#
# 🔍 STATISTICALLY SIGNIFICANT FINDINGS (α = 0.05):
# ----------------------------------------
# Based on Squared Error Loss (MSE):
#   • ARIMA-XGBoost > XGBoost (p < 0.05)
#   • ARIMA-XGBoost > LSTM-XGBoost (p < 0.01)
#   • ARIMA-XGBoost > LSTM (p < 0.01)
#   • ARIMA > ARIMA-LSTM (p < 0.01)
#   • ARIMA > XGBoost (p < 0.05)
#   • ARIMA > LSTM-XGBoost (p < 0.01)
#   • ARIMA > LSTM (p < 0.01)
#   • ARIMA-LSTM > XGBoost (p < 0.05)
#   • ARIMA-LSTM > LSTM-XGBoost (p < 0.01)
#   • ARIMA-LSTM > LSTM (p < 0.01)
#   • XGBoost > LSTM (p < 0.01)
#   • LSTM-XGBoost > LSTM (p < 0.01)
#
# Based on Absolute Error Loss (MAE):
#   • ARIMA-XGBoost > XGBoost (p < 0.01)
#   • ARIMA-XGBoost > LSTM-XGBoost (p < 0.01)
#   • ARIMA-XGBoost > LSTM (p < 0.01)
#   • ARIMA > XGBoost (p < 0.01)
#   • ARIMA > LSTM-XGBoost (p < 0.01)
#   • ARIMA > LSTM (p < 0.01)
#   • ARIMA-LSTM > XGBoost (p < 0.01)
#   • ARIMA-LSTM > LSTM-XGBoost (p < 0.01)
#   • ARIMA-LSTM > LSTM (p < 0.01)
#   • XGBoost > LSTM (p < 0.01)
#   • LSTM-XGBoost > LSTM (p < 0.01)
#
# 📊 INTERPRETATION:
# ----------------------------------------
# 1. Significance level α = 0.05 means we require 95% confidence
# 2. *** indicates p < 0.01 (99% confidence)
# 3. ** indicates p < 0.05 (95% confidence)
# 4. No asterisk means not statistically significant
# 5. 'Model A better than Model B' means Model A has significantly lower errors
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from typing import Dict
import warnings
warnings.filterwarnings('ignore')

# ============================================
# 1. LOAD ALL PREDICTION FILES
# ============================================

print("="*60)
print("DIEBOLD-MARIANO TESTS (α = 0.05)")
print("="*60)

# Load all CSV files
models_data = {
    'LSTM': pd.read_csv('lstm.csv', parse_dates=['Date']),
    'XGBoost': pd.read_csv('xgboost.csv', parse_dates=['Date']),
    'ARIMA': pd.read_csv('arima.csv', parse_dates=['Date']),
    'ARIMA-LSTM': pd.read_csv('arima_lstm.csv', parse_dates=['Date']),
    'ARIMA-XGBoost': pd.read_csv('arima_xgboost.csv', parse_dates=['Date']),
    'LSTM-XGBoost': pd.read_csv('lstm_xgboost.csv', parse_dates=['Date'])
}

# Standardize column names for consistency
for model_name, df in models_data.items():
    # Find the prediction column (non-Date, non-Actual)
    pred_col = [col for col in df.columns if col not in ['Date', 'Actual']][0]
    # Rename prediction column to standardized name
    df.rename(columns={pred_col: f'{model_name}_Predicted'}, inplace=True)

# Create a unified DataFrame with all predictions
unified_df = models_data['ARIMA'][['Date', 'Actual']].copy()

for model_name, df in models_data.items():
    pred_col = f'{model_name}_Predicted'
    unified_df[pred_col] = df[pred_col]

print("Loaded all prediction files:")
print(f"Total observations: {len(unified_df)}")
print(f"Date range: {unified_df['Date'].min().date()} to {unified_df['Date'].max().date()}")
print(f"Models: {list(models_data.keys())}")

# ============================================
# 2. CALCULATE RESIDUALS AND PERFORMANCE METRICS
# ============================================

print("\n" + "="*60)
print("MODEL PERFORMANCE METRICS")
print("="*60)

# Calculate residuals and performance metrics
metrics = {}
residuals_dict = {}

for model_name in models_data.keys():
    pred_col = f'{model_name}_Predicted'
    residuals = unified_df['Actual'] - unified_df[pred_col]
    residuals_dict[model_name] = residuals
    
    # Calculate metrics
    mse = np.mean(residuals**2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(residuals))
    mape = np.mean(np.abs(residuals / unified_df['Actual'])) * 100
    
    metrics[model_name] = {
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae,
        'MAPE': mape,
        'Mean_Residual': np.mean(residuals),
        'Std_Residual': np.std(residuals)
    }

# Create performance DataFrame
metrics_df = pd.DataFrame(metrics).T
metrics_df = metrics_df.sort_values('RMSE')

print("\nPerformance Metrics (sorted by RMSE):")
print("-" * 80)
print(metrics_df.round(4).to_string())
print("\n" + "-" * 80)
print(f"Best model by RMSE: {metrics_df.index[0]} ({metrics_df.iloc[0]['RMSE']:.2f})")
print(f"Worst model by RMSE: {metrics_df.index[-1]} ({metrics_df.iloc[-1]['RMSE']:.2f})")

# ============================================
# 3. DIEBOLD-MARIANO TEST IMPLEMENTATION (α = 0.05)
# ============================================

def diebold_mariano_test(residuals1: pd.Series, residuals2: pd.Series, 
                        h: int = 1, loss_type: str = 'squared') -> Dict:
    """
    Perform Diebold-Mariano test for comparing two forecast models.
    
    Parameters:
    -----------
    residuals1 : pd.Series
        Residuals from model 1 (actual - predicted)
    residuals2 : pd.Series
        Residuals from model 2 (actual - predicted)
    h : int
        Forecast horizon (default=1 for one-step ahead)
    loss_type : str
        Loss function: 'squared' (MSE) or 'absolute' (MAE)
    
    Returns:
    --------
    dict : Test results including DM statistic and p-values
    """
    from scipy.stats import norm
    
    # Ensure equal length
    n = min(len(residuals1), len(residuals2))
    residuals1 = residuals1.iloc[:n]
    residuals2 = residuals2.iloc[:n]
    
    # Calculate loss differential
    if loss_type == 'squared':
        d = residuals1**2 - residuals2**2
    elif loss_type == 'absolute':
        d = np.abs(residuals1) - np.abs(residuals2)
    else:
        raise ValueError("loss_type must be 'squared' or 'absolute'")
    
    # Calculate mean and variance of loss differential
    mean_d = np.mean(d)
    var_d = np.var(d, ddof=1)  # Sample variance
    
    # Calculate DM statistic
    dm_stat = mean_d / np.sqrt(var_d / n)
    
    # Calculate p-values (two-tailed test)
    p_value_two_tailed = 2 * (1 - norm.cdf(abs(dm_stat)))
    p_value_one_tailed_better = 1 - norm.cdf(dm_stat)  # H1: model2 better than model1
    p_value_one_tailed_worse = norm.cdf(dm_stat)       # H1: model2 worse than model1
    
    # Bartlett's small-sample correction
    bartlett_factor = 1 + (h - 1) / n
    dm_stat_corrected = dm_stat / np.sqrt(bartlett_factor)
    p_value_two_tailed_corrected = 2 * (1 - norm.cdf(abs(dm_stat_corrected)))
    
    return {
        'DM_Statistic': dm_stat,
        'DM_Statistic_Corrected': dm_stat_corrected,
        'P_Value_Two_Tailed': p_value_two_tailed,
        'P_Value_Two_Tailed_Corrected': p_value_two_tailed_corrected,
        'P_Value_One_Tailed_Better': p_value_one_tailed_better,
        'P_Value_One_Tailed_Worse': p_value_one_tailed_worse,
        'Mean_Loss_Differential': mean_d,
        'Std_Loss_Differential': np.sqrt(var_d),
        'Sample_Size': n,
        'Loss_Type': loss_type
    }

# ============================================
# 4. PERFORM PAIRWISE DIEBOLD-MARIANO TESTS (α = 0.05)
# ============================================

print("\n" + "="*80)
print("DIEBOLD-MARIANO TESTS - MODEL COMPARISONS (α = 0.05)")
print("="*80)

# Get model names in sorted order by RMSE (best to worst)
model_names_sorted = list(metrics_df.index)

# Perform pairwise DM tests
dm_results = {}
model_pairs = []

for i, model1 in enumerate(model_names_sorted):
    for model2 in model_names_sorted[i+1:]:
        pair_key = f"{model1} vs {model2}"
        model_pairs.append(pair_key)
        
        # Get residuals
        res1 = residuals_dict[model1]
        res2 = residuals_dict[model2]
        
        # Perform DM test with both loss functions
        dm_squared = diebold_mariano_test(res1, res2, h=1, loss_type='squared')
        dm_absolute = diebold_mariano_test(res1, res2, h=1, loss_type='absolute')
        
        dm_results[pair_key] = {
            'Squared_Error': dm_squared,
            'Absolute_Error': dm_absolute
        }

# ============================================
# 5. DISPLAY DM TEST RESULTS WITH CRITICAL VALUES
# ============================================

# Critical values for α = 0.05
critical_value_two_tailed = norm.ppf(1 - 0.05/2)  # ±1.96 for two-tailed
critical_value_one_tailed = norm.ppf(1 - 0.05)    # 1.645 for one-tailed

print("\n" + "="*80)
print("DIEBOLD-MARIANO TEST RESULTS (Squared Error Loss)")
print("="*80)
print("\nH₀: The two models have equal predictive accuracy")
print("H₁: The two models have different predictive accuracy")
print(f"Significance level: α = 0.05")
print(f"Critical values: ±{critical_value_two_tailed:.3f} (two-tailed), {critical_value_one_tailed:.3f} (one-tailed)")
print("\nDECISION RULE:")
print(f"- Reject H₀ if |DM Statistic| > {critical_value_two_tailed:.3f} (two-tailed)")
print(f"- Reject H₀ if DM Statistic > {critical_value_one_tailed:.3f} (model 2 better than model 1)")
print(f"- Reject H₀ if DM Statistic < -{critical_value_one_tailed:.3f} (model 1 better than model 2)\n")

print(f"{'Model Pair':<25} {'DM Stat':<10} {'P-Value':<12} {'Sig.':<8} {'Reject H₀?':<12} {'Conclusion':<30}")
print("-" * 107)

for pair in model_pairs:
    dm_info = dm_results[pair]['Squared_Error']
    dm_stat = dm_info['DM_Statistic_Corrected']
    p_value = dm_info['P_Value_Two_Tailed_Corrected']
    abs_dm_stat = abs(dm_stat)
    
    # Determine if we reject H₀
    reject_h0 = "YES" if abs_dm_stat > critical_value_two_tailed else "NO"
    
    # Determine significance (α = 0.05)
    if p_value < 0.01:
        sig = "***"
    elif p_value < 0.05:
        sig = "**"
    else:
        sig = ""
    
    # Determine which model is better
    model1, model2 = pair.split(" vs ")
    mean_diff = dm_info['Mean_Loss_Differential']
    
    if mean_diff > 0:
        # Model1 has higher loss (worse) than Model2
        better_model = model2
        worse_model = model1
        conclusion = f"{model2} better than {model1}"
    else:
        # Model1 has lower loss (better) than Model2
        better_model = model1
        worse_model = model2
        conclusion = f"{model1} better than {model2}"
    
    # Only show conclusion if significant at 5% level (α = 0.05)
    if p_value >= 0.05:
        conclusion = "No significant difference"
    
    print(f"{pair:<25} {dm_stat:>8.3f} {p_value:>11.4f} {sig:^8} {reject_h0:^12} {conclusion:<30}")

print("\n" + "="*80)
print("DIEBOLD-MARIANO TEST RESULTS (Absolute Error Loss)")
print("="*80)
print("\nH₀: The two models have equal predictive accuracy")
print("H₁: The two models have different predictive accuracy")
print(f"Significance level: α = 0.05")
print(f"Critical values: ±{critical_value_two_tailed:.3f} (two-tailed), {critical_value_one_tailed:.3f} (one-tailed)")
print("\nDECISION RULE:")
print(f"- Reject H₀ if |DM Statistic| > {critical_value_two_tailed:.3f} (two-tailed)")
print(f"- Reject H₀ if DM Statistic > {critical_value_one_tailed:.3f} (model 2 better than model 1)")
print(f"- Reject H₀ if DM Statistic < -{critical_value_one_tailed:.3f} (model 1 better than model 2)\n")

print(f"{'Model Pair':<25} {'DM Stat':<10} {'P-Value':<12} {'Sig.':<8} {'Reject H₀?':<12} {'Conclusion':<30}")
print("-" * 107)

for pair in model_pairs:
    dm_info = dm_results[pair]['Absolute_Error']
    dm_stat = dm_info['DM_Statistic_Corrected']
    p_value = dm_info['P_Value_Two_Tailed_Corrected']
    abs_dm_stat = abs(dm_stat)
    
    # Determine if we reject H₀
    reject_h0 = "YES" if abs_dm_stat > critical_value_two_tailed else "NO"
    
    # Determine significance (α = 0.05)
    if p_value < 0.01:
        sig = "***"
    elif p_value < 0.05:
        sig = "**"
    else:
        sig = ""
    
    # Determine which model is better
    model1, model2 = pair.split(" vs ")
    mean_diff = dm_info['Mean_Loss_Differential']
    
    if mean_diff > 0:
        # Model1 has higher loss (worse) than Model2
        better_model = model2
        worse_model = model1
        conclusion = f"{model2} better than {model1}"
    else:
        # Model1 has lower loss (better) than Model2
        better_model = model1
        worse_model = model2
        conclusion = f"{model1} better than {model2}"
    
    # Only show conclusion if significant at 5% level (α = 0.05)
    if p_value >= 0.05:
        conclusion = "No significant difference"
    
    print(f"{pair:<25} {dm_stat:>8.3f} {p_value:>11.4f} {sig:^8} {reject_h0:^12} {conclusion:<30}")

# ============================================
# 6. CREATE SUMMARY OF SIGNIFICANT DIFFERENCES (α = 0.05)
# ============================================

print("\n" + "="*80)
print("SUMMARY OF SIGNIFICANT DIFFERENCES (α = 0.05)")
print("="*80)
print(f"Critical value for rejection: |DM| > {critical_value_two_tailed:.3f}")

print("\nSIGNIFICANT DIFFERENCES (Squared Error Loss):")
print("-" * 60)

significant_pairs_squared = []
for pair in model_pairs:
    dm_stat = dm_results[pair]['Squared_Error']['DM_Statistic_Corrected']
    p_value = dm_results[pair]['Squared_Error']['P_Value_Two_Tailed_Corrected']
    if abs(dm_stat) > critical_value_two_tailed:  # Reject H₀
        model1, model2 = pair.split(" vs ")
        mean_diff = dm_results[pair]['Squared_Error']['Mean_Loss_Differential']
        
        if mean_diff > 0:
            better = model2
            worse = model1
        else:
            better = model1
            worse = model2
        
        significance = ""
        if p_value < 0.01:
            significance = "(p < 0.01)"
        else:
            significance = "(p < 0.05)"
        
        significant_pairs_squared.append((pair, better, worse, p_value, significance, dm_stat))
        print(f"  • {better} significantly better than {worse} {significance} |DM|={abs(dm_stat):.3f}")

if not significant_pairs_squared:
    print(f"  No significant differences found at α = 0.05 (|DM| > {critical_value_two_tailed:.3f})")

print("\nSIGNIFICANT DIFFERENCES (Absolute Error Loss):")
print("-" * 60)

significant_pairs_absolute = []
for pair in model_pairs:
    dm_stat = dm_results[pair]['Absolute_Error']['DM_Statistic_Corrected']
    p_value = dm_results[pair]['Absolute_Error']['P_Value_Two_Tailed_Corrected']
    if abs(dm_stat) > critical_value_two_tailed:  # Reject H₀
        model1, model2 = pair.split(" vs ")
        mean_diff = dm_results[pair]['Absolute_Error']['Mean_Loss_Differential']
        
        if mean_diff > 0:
            better = model2
            worse = model1
        else:
            better = model1
            worse = model2
        
        significance = ""
        if p_value < 0.01:
            significance = "(p < 0.01)"
        else:
            significance = "(p < 0.05)"
        
        significant_pairs_absolute.append((pair, better, worse, p_value, significance, dm_stat))
        print(f"  • {better} significantly better than {worse} {significance} |DM|={abs(dm_stat):.3f}")

if not significant_pairs_absolute:
    print(f"  No significant differences found at α = 0.05 (|DM| > {critical_value_two_tailed:.3f})")

# ============================================
# 7. RESIDUALS PLOT (ALL 6 MODELS)
# ============================================

print("\n" + "="*80)
print("RESIDUALS PLOT - ALL 6 MODELS")
print("="*80)

# Define color palette for models
model_colors = {
    'LSTM': 'blue',
    'XGBoost': 'green',
    'ARIMA': 'red',
    'ARIMA-LSTM': 'purple',
    'ARIMA-XGBoost': 'orange',
    'LSTM-XGBoost': 'brown'
}

# Define line styles for better differentiation
line_styles = {
    'LSTM': '-',
    'XGBoost': '-',
    'ARIMA': '-',
    'ARIMA-LSTM': '-',
    'ARIMA-XGBoost': '-',
    'LSTM-XGBoost': '-'
}

# Create figure
plt.figure(figsize=(15, 8))

# Plot each model's residuals
for model_name, residuals in residuals_dict.items():
    plt.plot(unified_df['Date'], residuals, 
             label=model_name, 
             color=model_colors[model_name],
             linestyle=line_styles[model_name],
             linewidth=2,
             alpha=0.8)

# Add zero reference line
plt.axhline(y=0, color='black', linestyle='-', linewidth=1, alpha=0.5, label='Zero Line')

# Add grid for better readability
plt.grid(True, alpha=0.3, linestyle='--')

# Customize plot
plt.xlabel('Date', fontsize=12)
plt.ylabel('Residuals', fontsize=12)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10, framealpha=0.9)

# Rotate date labels for better readability
plt.xticks(rotation=45)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Show plot
plt.show()

# ============================================
# 8. FINAL SUMMARY WITH CRITICAL VALUES
# ============================================

print("\n" + "="*80)
print("FINAL SUMMARY WITH CRITICAL VALUES (α = 0.05)")
print("="*80)

print("\n🏆 PERFORMANCE RANKING (Based on RMSE):")
print("-" * 40)
for i, (model_name, row) in enumerate(metrics_df.iterrows(), 1):
    print(f"{i}. {model_name}: RMSE = {row['RMSE']:.2f}, MAE = {row['MAE']:.2f}")

print("\n🔍 STATISTICALLY SIGNIFICANT FINDINGS (α = 0.05):")
print("-" * 40)

if significant_pairs_squared:
    print(f"Based on Squared Error Loss (MSE) - Critical value: |DM| > {critical_value_two_tailed:.3f}")
    for pair, better, worse, p_val, sig, dm_stat in significant_pairs_squared:
        print(f"  • {better} > {worse} {sig} (DM={dm_stat:.3f})")
else:
    print(f"No statistically significant differences found with squared error loss (|DM| > {critical_value_two_tailed:.3f})")

if significant_pairs_absolute:
    print(f"\nBased on Absolute Error Loss (MAE) - Critical value: |DM| > {critical_value_two_tailed:.3f}")
    for pair, better, worse, p_val, sig, dm_stat in significant_pairs_absolute:
        print(f"  • {better} > {worse} {sig} (DM={dm_stat:.3f})")
else:
    print(f"No statistically significant differences found with absolute error loss (|DM| > {critical_value_two_tailed:.3f})")

print("\n📊 DIEBOLD-MARIANO TEST INTERPRETATION:")
print("-" * 40)
print(f"1. Significance level: α = 0.05")
print(f"2. Critical values for rejection:")
print(f"   • Two-tailed test: |DM| > {critical_value_two_tailed:.3f}")
print(f"   • One-tailed test (right): DM > {critical_value_one_tailed:.3f}")
print(f"   • One-tailed test (left): DM < -{critical_value_one_tailed:.3f}")
print(f"3. *** indicates p < 0.01 (99% confidence)")
print(f"4. ** indicates p < 0.05 (95% confidence)")
print(f"5. No asterisk means not statistically significant")
print(f"6. 'Model A better than Model B' means Model A has significantly lower errors")

print("\n📈 DECISION RULES SUMMARY:")
print("-" * 40)
print("• For two-tailed test (H₁: models have different accuracy):")
print(f"  - Reject H₀ if |DM Statistic| > {critical_value_two_tailed:.3f}")
print("• For one-tailed test (H₁: model 2 is better than model 1):")
print(f"  - Reject H₀ if DM Statistic > {critical_value_one_tailed:.3f}")
print("• For one-tailed test (H₁: model 1 is better than model 2):")
print(f"  - Reject H₀ if DM Statistic < -{critical_value_one_tailed:.3f}")

print("\n" + "="*80)
print("ANALYSIS COMPLETE")
print("="*80)
# Out:
# ============================================================
# DIEBOLD-MARIANO TESTS (α = 0.05)
# ============================================================
# Loaded all prediction files:
# Total observations: 30
# Date range: 2025-08-29 to 2025-10-09
# Models: ['LSTM', 'XGBoost', 'ARIMA', 'ARIMA-LSTM', 'ARIMA-XGBoost', 'LSTM-XGBoost']
#
# ============================================================
# MODEL PERFORMANCE METRICS
# ============================================================
#
# Performance Metrics (sorted by RMSE):
# --------------------------------------------------------------------------------
#                    MSE    RMSE     MAE    MAPE  Mean_Residual  Std_Residual
# ARIMA-XGBoost   5.3523  2.3135  1.6244  0.8224        -0.2222        2.3028
# ARIMA           5.3675  2.3168  1.6141  0.8171        -0.1942        2.3086
# ARIMA-LSTM      5.4646  2.3377  1.6301  0.8253        -0.2210        2.3272
# XGBoost         9.8652  3.1409  2.8006  1.4199        -1.1846        2.9089
# LSTM-XGBoost   13.9165  3.7305  3.2720  1.6550         0.4493        3.7033
# LSTM           47.9918  6.9276  5.8420  2.9651         2.0832        6.6070
#
# --------------------------------------------------------------------------------
# Best model by RMSE: ARIMA-XGBoost (2.31)
# Worst model by RMSE: LSTM (6.93)
#
# ================================================================================
# DIEBOLD-MARIANO TESTS - MODEL COMPARISONS (α = 0.05)
# ================================================================================
#
# ================================================================================
# DIEBOLD-MARIANO TEST RESULTS (Squared Error Loss)
# ================================================================================
#
# H₀: The two models have equal predictive accuracy
# H₁: The two models have different predictive accuracy
# Significance level: α = 0.05
# Critical values: ±1.960 (two-tailed), 1.645 (one-tailed)
#
# DECISION RULE:
# - Reject H₀ if |DM Statistic| > 1.960 (two-tailed)
# - Reject H₀ if DM Statistic > 1.645 (model 2 better than model 1)
# - Reject H₀ if DM Statistic < -1.645 (model 1 better than model 2)
#
# Model Pair                DM Stat    P-Value      Sig.     Reject H₀?   Conclusion
# -----------------------------------------------------------------------------------------------------------
# ARIMA-XGBoost vs ARIMA      -0.157      0.8750               NO      No significant difference
# ARIMA-XGBoost vs ARIMA-LSTM   -1.167      0.2431               NO      No significant difference
# ARIMA-XGBoost vs XGBoost    -2.217      0.0266    **        YES      ARIMA-XGBoost better than XGBoost
# ARIMA-XGBoost vs LSTM-XGBoost   -3.050      0.0023   ***        YES      ARIMA-XGBoost better than LSTM-XGBoost
# ARIMA-XGBoost vs LSTM       -4.437      0.0000   ***        YES      ARIMA-XGBoost better than LSTM
# ARIMA vs ARIMA-LSTM         -2.706      0.0068   ***        YES      ARIMA better than ARIMA-LSTM
# ARIMA vs XGBoost            -2.200      0.0278    **        YES      ARIMA better than XGBoost
# ARIMA vs LSTM-XGBoost       -3.035      0.0024   ***        YES      ARIMA better than LSTM-XGBoost
# ARIMA vs LSTM               -4.429      0.0000   ***        YES      ARIMA better than LSTM
# ARIMA-LSTM vs XGBoost       -2.137      0.0326    **        YES      ARIMA-LSTM better than XGBoost
# ARIMA-LSTM vs LSTM-XGBoost   -2.986      0.0028   ***        YES      ARIMA-LSTM better than LSTM-XGBoost
# ARIMA-LSTM vs LSTM          -4.418      0.0000   ***        YES      ARIMA-LSTM better than LSTM
# XGBoost vs LSTM-XGBoost     -1.398      0.1623               NO      No significant difference
# XGBoost vs LSTM             -3.907      0.0001   ***        YES      XGBoost better than LSTM
# LSTM-XGBoost vs LSTM        -4.166      0.0000   ***        YES      LSTM-XGBoost better than LSTM
#
# ================================================================================
# DIEBOLD-MARIANO TEST RESULTS (Absolute Error Loss)
# ================================================================================
#
# H₀: The two models have equal predictive accuracy
# H₁: The two models have different predictive accuracy
# Significance level: α = 0.05
# Critical values: ±1.960 (two-tailed), 1.645 (one-tailed)
#
# DECISION RULE:
# - Reject H₀ if |DM Statistic| > 1.960 (two-tailed)
# - Reject H₀ if DM Statistic > 1.645 (model 2 better than model 1)
# - Reject H₀ if DM Statistic < -1.645 (model 1 better than model 2)
#
# Model Pair                DM Stat    P-Value      Sig.     Reject H₀?   Conclusion
# -----------------------------------------------------------------------------------------------------------
# ARIMA-XGBoost vs ARIMA       0.445      0.6560               NO      No significant difference
# ARIMA-XGBoost vs ARIMA-LSTM   -0.227      0.8202               NO      No significant difference
# ARIMA-XGBoost vs XGBoost    -4.124      0.0000   ***        YES      ARIMA-XGBoost better than XGBoost
# ARIMA-XGBoost vs LSTM-XGBoost   -3.559      0.0004   ***        YES      ARIMA-XGBoost better than LSTM-XGBoost
# ARIMA-XGBoost vs LSTM       -5.654      0.0000   ***        YES      ARIMA-XGBoost better than LSTM
# ARIMA vs ARIMA-LSTM         -1.512      0.1306               NO      No significant difference
# ARIMA vs XGBoost            -4.090      0.0000   ***        YES      ARIMA better than XGBoost
# ARIMA vs LSTM-XGBoost       -3.552      0.0004   ***        YES      ARIMA better than LSTM-XGBoost
# ARIMA vs LSTM               -5.658      0.0000   ***        YES      ARIMA better than LSTM
# ARIMA-LSTM vs XGBoost       -4.054      0.0001   ***        YES      ARIMA-LSTM better than XGBoost
# ARIMA-LSTM vs LSTM-XGBoost   -3.520      0.0004   ***        YES      ARIMA-LSTM better than LSTM-XGBoost
# ARIMA-LSTM vs LSTM          -5.637      0.0000   ***        YES      ARIMA-LSTM better than LSTM
# XGBoost vs LSTM-XGBoost     -1.099      0.2719               NO      No significant difference
# XGBoost vs LSTM             -4.238      0.0000   ***        YES      XGBoost better than LSTM
# LSTM-XGBoost vs LSTM        -4.875      0.0000   ***        YES      LSTM-XGBoost better than LSTM
#
# ================================================================================
# SUMMARY OF SIGNIFICANT DIFFERENCES (α = 0.05)
# ================================================================================
# Critical value for rejection: |DM| > 1.960
#
# SIGNIFICANT DIFFERENCES (Squared Error Loss):
# ------------------------------------------------------------
#   • ARIMA-XGBoost significantly better than XGBoost (p < 0.05) |DM|=2.217
#   • ARIMA-XGBoost significantly better than LSTM-XGBoost (p < 0.01) |DM|=3.050
#   • ARIMA-XGBoost significantly better than LSTM (p < 0.01) |DM|=4.437
#   • ARIMA significantly better than ARIMA-LSTM (p < 0.01) |DM|=2.706
#   • ARIMA significantly better than XGBoost (p < 0.05) |DM|=2.200
#   • ARIMA significantly better than LSTM-XGBoost (p < 0.01) |DM|=3.035
#   • ARIMA significantly better than LSTM (p < 0.01) |DM|=4.429
#   • ARIMA-LSTM significantly better than XGBoost (p < 0.05) |DM|=2.137
#   • ARIMA-LSTM significantly better than LSTM-XGBoost (p < 0.01) |DM|=2.986
#   • ARIMA-LSTM significantly better than LSTM (p < 0.01) |DM|=4.418
#   • XGBoost significantly better than LSTM (p < 0.01) |DM|=3.907
#   • LSTM-XGBoost significantly better than LSTM (p < 0.01) |DM|=4.166
#
# SIGNIFICANT DIFFERENCES (Absolute Error Loss):
# ------------------------------------------------------------
#   • ARIMA-XGBoost significantly better than XGBoost (p < 0.01) |DM|=4.124
#   • ARIMA-XGBoost significantly better than LSTM-XGBoost (p < 0.01) |DM|=3.559
#   • ARIMA-XGBoost significantly better than LSTM (p < 0.01) |DM|=5.654
#   • ARIMA significantly better than XGBoost (p < 0.01) |DM|=4.090
#   • ARIMA significantly better than LSTM-XGBoost (p < 0.01) |DM|=3.552
#   • ARIMA significantly better than LSTM (p < 0.01) |DM|=5.658
#   • ARIMA-LSTM significantly better than XGBoost (p < 0.01) |DM|=4.054
#   • ARIMA-LSTM significantly better than LSTM-XGBoost (p < 0.01) |DM|=3.520
#   • ARIMA-LSTM significantly better than LSTM (p < 0.01) |DM|=5.637
#   • XGBoost significantly better than LSTM (p < 0.01) |DM|=4.238
#   • LSTM-XGBoost significantly better than LSTM (p < 0.01) |DM|=4.875
#
# ================================================================================
# RESIDUALS PLOT - ALL 6 MODELS
# ================================================================================
# ================================================================================
# FINAL SUMMARY WITH CRITICAL VALUES (α = 0.05)
# ================================================================================
#
# 🏆 PERFORMANCE RANKING (Based on RMSE):
# ----------------------------------------
# 1. ARIMA-XGBoost: RMSE = 2.31, MAE = 1.62
# 2. ARIMA: RMSE = 2.32, MAE = 1.61
# 3. ARIMA-LSTM: RMSE = 2.34, MAE = 1.63
# 4. XGBoost: RMSE = 3.14, MAE = 2.80
# 5. LSTM-XGBoost: RMSE = 3.73, MAE = 3.27
# 6. LSTM: RMSE = 6.93, MAE = 5.84
#
# 🔍 STATISTICALLY SIGNIFICANT FINDINGS (α = 0.05):
# ----------------------------------------
# Based on Squared Error Loss (MSE) - Critical value: |DM| > 1.960
#   • ARIMA-XGBoost > XGBoost (p < 0.05) (DM=-2.217)
#   • ARIMA-XGBoost > LSTM-XGBoost (p < 0.01) (DM=-3.050)
#   • ARIMA-XGBoost > LSTM (p < 0.01) (DM=-4.437)
#   • ARIMA > ARIMA-LSTM (p < 0.01) (DM=-2.706)
#   • ARIMA > XGBoost (p < 0.05) (DM=-2.200)
#   • ARIMA > LSTM-XGBoost (p < 0.01) (DM=-3.035)
#   • ARIMA > LSTM (p < 0.01) (DM=-4.429)
#   • ARIMA-LSTM > XGBoost (p < 0.05) (DM=-2.137)
#   • ARIMA-LSTM > LSTM-XGBoost (p < 0.01) (DM=-2.986)
#   • ARIMA-LSTM > LSTM (p < 0.01) (DM=-4.418)
#   • XGBoost > LSTM (p < 0.01) (DM=-3.907)
#   • LSTM-XGBoost > LSTM (p < 0.01) (DM=-4.166)
#
# Based on Absolute Error Loss (MAE) - Critical value: |DM| > 1.960
#   • ARIMA-XGBoost > XGBoost (p < 0.01) (DM=-4.124)
#   • ARIMA-XGBoost > LSTM-XGBoost (p < 0.01) (DM=-3.559)
#   • ARIMA-XGBoost > LSTM (p < 0.01) (DM=-5.654)
#   • ARIMA > XGBoost (p < 0.01) (DM=-4.090)
#   • ARIMA > LSTM-XGBoost (p < 0.01) (DM=-3.552)
#   • ARIMA > LSTM (p < 0.01) (DM=-5.658)
#   • ARIMA-LSTM > XGBoost (p < 0.01) (DM=-4.054)
#   • ARIMA-LSTM > LSTM-XGBoost (p < 0.01) (DM=-3.520)
#   • ARIMA-LSTM > LSTM (p < 0.01) (DM=-5.637)
#   • XGBoost > LSTM (p < 0.01) (DM=-4.238)
#   • LSTM-XGBoost > LSTM (p < 0.01) (DM=-4.875)
#
# 📊 DIEBOLD-MARIANO TEST INTERPRETATION:
# ----------------------------------------
# 1. Significance level: α = 0.05
# 2. Critical values for rejection:
#    • Two-tailed test: |DM| > 1.960
#    • One-tailed test (right): DM > 1.645
#    • One-tailed test (left): DM < -1.645
# 3. *** indicates p < 0.01 (99% confidence)
# 4. ** indicates p < 0.05 (95% confidence)
# 5. No asterisk means not statistically significant
# 6. 'Model A better than Model B' means Model A has significantly lower errors
#
# 📈 DECISION RULES SUMMARY:
# ----------------------------------------
# • For two-tailed test (H₁: models have different accuracy):
#   - Reject H₀ if |DM Statistic| > 1.960
# • For one-tailed test (H₁: model 2 is better than model 1):
#   - Reject H₀ if DM Statistic > 1.645
# • For one-tailed test (H₁: model 1 is better than model 2):
#   - Reject H₀ if DM Statistic < -1.645
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================
